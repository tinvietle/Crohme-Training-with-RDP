# %% [markdown]
# # Temporal sequence classification: CROHME dataset
#
# Dataset:
# https://www.cs.rit.edu/~rlaz/files/CROHME+TFD%E2%80%932019.pdf
#
# Objective:
#
# - Recognize handwriting input sequences (mathematical expression)
# - Output sequence of symbols + relations based on Symbol Relation Tree and Writing Order
#
# ![image.png](attachment:63358e0a-363d-43a8-9cac-a690f218add1.png)![image.png](attachment:fd744812-6788-4939-9690-0967d44ee52c.png)
#
# Method:
# - Use recurrent neural networks (Bi-directional LSTM).
# - Training: supervised learning using pairs of input sequence and target sequence.
# - Loss function: CTC loss function to learn temporal classification.
# https://pytorch.org/docs/stable/generated/torch.nn.CTCLoss.html

# %% [markdown]
# ## Task 1: Dataset & Dataloader

# %% [markdown]
# ### Overview
#
# We need to build the Dataset class which read the input samples, annotation files and return the pair of <input, target> for each sample.
#
# The target should follow the description of CTC loss function. "Each element in the target sequence is a class index".
#
# ![image.png](attachment:5aed9256-89aa-4b21-9416-8dd26b556a38.png)

# %% [markdown]
# Example:
#
# We have an inkml file: "crohme2019/test/UN19_1041_em_597.inkml"
# Its label is "- Right \sqrt Inside 2"
#
# Target would be: [[5, 50, 35, 51, 12]], where the index here is the index of tokens (from a vocabulary)

# %% [markdown]
# ### Task 1.1 Build vocab
#
# The first task is build the vocabulary from the dataset. From the target of the annotation files, extract and unique the token list to get the vocabulary. (Find the set of symbols and relations from labeled dataset).
#
# Input:
#
# ```
# /kaggle/input/crohme2019/crohme2019_train.txt
# /kaggle/input/crohme2019/crohme2019_valid.txt
# /kaggle/input/crohme2019/crohme2019_test.txt
# ```
# Output:
# ```
# crohme_vocab.txt
# ```

# %%
input_files = ['crohme2019_train.txt',
'crohme2019_valid.txt',
'crohme2019_test.txt']

vocab = set()

for input_file in input_files:
    for line in open(input_file).readlines():
        if len(line.strip().split('\t')) == 2:
            vocab.update(line.strip().split('\t')[1].split())

# %%
vocab_syms = [v for v in vocab if v not in ['Above', 'Below', 'Inside', 'NoRel', 'Right', 'Sub', 'Sup']]

# %%
with open('crohme_vocab.txt', 'w') as f:
    f.writelines([c + '\n' for c in sorted(vocab_syms)])
    f.writelines([c + '\n' for c in ['Above', 'Below', 'Inside', 'NoRel', 'Right', 'Sub', 'Sup']])

# %%
class Vocab(object):
    def __init__(self, vocab_file=None):
        self.word2index = {}
        self.index2word = {}

        if vocab_file:
            self.load_vocab(vocab_file)

    def load_vocab(self, vocab_file):
        # load vocab from file
        with open(vocab_file, 'r') as f:
            for i, line in enumerate(f):
                word = line.strip()
                self.word2index[word] = i
                self.index2word[i] = word
        # add blank word
        self.word2index['<blank>'] = len(self.word2index)
        self.index2word[self.word2index['<blank>']] = '<blank>'

# %% [markdown]
# #### Vocab class

# %%
vocab = Vocab(vocab_file = 'crohme_vocab.txt')

# %%
vocab.index2word
# Out:
# {0: '!',
#  1: '(',
#  2: ')',
#  3: '+',
#  4: '-',
#  5: '.',
#  6: '/',
#  7: '0',
#  8: '1',
#  9: '2',
#  10: '3',
#  11: '4',
#  12: '5',
#  13: '6',
#  14: '7',
#  15: '8',
#  16: '9',
#  17: '=',
#  18: 'A',
#  19: 'B',
#  20: 'C',
#  21: 'COMMA',
#  22: 'E',
#  23: 'F',
#  24: 'G',
#  25: 'H',
#  26: 'I',
#  27: 'L',
#  28: 'M',
#  29: 'N',
#  30: 'P',
#  31: 'R',
#  32: 'S',
#  33: 'T',
#  34: 'V',
#  35: 'X',
#  36: 'Y',
#  37: '[',
#  38: '\\Delta',
#  39: '\\alpha',
#  40: '\\beta',
#  41: '\\cos',
#  42: '\\div',
#  43: '\\exists',
#  44: '\\forall',
#  45: '\\gamma',
#  46: '\\geq',
#  47: '\\gt',
#  48: '\\in',
#  49: '\\infty',
#  50: '\\int',
#  51: '\\lambda',
#  52: '\\ldots',
#  53: '\\leq',
#  54: '\\lim',
#  55: '\\log',
#  56: '\\lt',
#  57: '\\mu',
#  58: '\\neq',
#  59: '\\phi',
#  60: '\\pi',
#  61: '\\pm',
#  62: '\\prime',
#  63: '\\rightarrow',
#  64: '\\sigma',
#  65: '\\sin',
#  66: '\\sqrt',
#  67: '\\sum',
#  68: '\\tan',
#  69: '\\theta',
#  70: '\\times',
#  71: '\\{',
#  72: '\\}',
#  73: ']',
#  74: 'a',
#  75: 'b',
#  76: 'c',
#  77: 'd',
#  78: 'e',
#  79: 'f',
#  80: 'g',
#  81: 'h',
#  82: 'i',
#  83: 'j',
#  84: 'k',
#  85: 'l',
#  86: 'm',
#  87: 'n',
#  88: 'o',
#  89: 'p',
#  90: 'q',
#  91: 'r',
#  92: 's',
#  93: 't',
#  94: 'u',
#  95: 'v',
#  96: 'w',
#  97: 'x',
#  98: 'y',
#  99: 'z',
#  100: '|',
#  101: 'Above',
#  102: 'Below',
#  103: 'Inside',
#  104: 'NoRel',
#  105: 'Right',
#  106: 'Sub',
#  107: 'Sup',
#  108: '<blank>'}

# %%
## test vocab
vocab = Vocab('crohme_vocab.txt')
input = '- Right \\sqrt Inside 2'.split()
output = [vocab.word2index[word] for word in input]
output
assert output == [4, 105, 66, 103, 9]

# %% [markdown]
# ### Task 1.2: Write dataset class
#
# In this task, we will build a dataset class that will be used to load the dataset files _(train, valid, and test)_.
#
# The dataset class will also be used to preprocess the data by converting the characters in the data to integers using the vocabulary.
#
# > _Before going to this task, it is **highly recommended** to read this [Tutorial on creating Custom Dataset](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files) with PyTorch._
# >
# > _You should have basic understanding of required methods in the Dataset class such as `__init__`, `__len__`, and `__getitem__`._
#
#
# ***Input***: Dataset class should take the following arguments:.
#
# - `annotation`: the path to the dataset annotation *(`.txt`)*.
# - `root_dir`: the root directory of the dataset file.
# - `vocab`: the vocabulary.
#
# ***Output***: the dataset class.
#
# > *Note: You can adjust the Dataset class base on your references.*

# %% [markdown]
# #### How to handle an InkML files
#
# Visualize InkML file
# https://www.cs.rit.edu/~rlaz/inkml_viewer/index.xhtml
#
#
# Below is a class structure for handling `.inkml` files.

# %%
import numpy as np

import xml.etree.ElementTree as ET

class Segment(object):
    """Class to reprsent a Segment compound of strokes (id) with an id and label."""
    __slots__ = ('id', 'label' ,'strId')
    def __init__(self, *args):
        if len(args) == 3:
            self.id = args[0]
            self.label = args[1]
            self.strId = args[2]
        else:
            self.id = "none"
            self.label = ""
            self.strId = set([])

class Inkml(object):
    """Class to represent an INKML file with strokes, segmentation and labels"""
    __slots__ = ('fileName', 'strokes', 'strkOrder','segments','truth','UI')

    NS = {'ns': 'http://www.w3.org/2003/InkML', 'xml': 'http://www.w3.org/XML/1998/namespace'}

    def __init__(self,*args):
        self.fileName = None
        self.strokes = {}
        self.strkOrder = []
        self.segments = {}
        self.truth = ""
        self.UI = ""
        if len(args) == 1:
            self.fileName = args[0]
            self.loadFromFile()

    def fixNS(self,ns,att):
        """Build the right tag or element name with namespace"""
        return '{'+Inkml.NS[ns]+'}'+att

    def loadFromFile(self):
        """load the ink from an inkml file (strokes, segments, labels)"""
        tree = ET.parse(self.fileName)
        # # ET.register_namespace();
        root = tree.getroot()
        for info in root.findall('ns:annotation',namespaces=Inkml.NS):
            if 'type' in info.attrib:
                if info.attrib['type'] == 'truth':
                    self.truth = info.text.strip()
                if info.attrib['type'] == 'UI':
                    self.UI = info.text.strip()
        for strk in root.findall('ns:trace',namespaces=Inkml.NS):
            self.strokes[strk.attrib['id']] = strk.text.strip()
            self.strkOrder.append(strk.attrib['id'])
        segments = root.find('ns:traceGroup',namespaces=Inkml.NS)
        if segments is None or len(segments) == 0:
            return
        for seg in (segments.iterfind('ns:traceGroup',namespaces=Inkml.NS)):
            id = seg.attrib[self.fixNS('xml','id')]
            label = seg.find('ns:annotation',namespaces=Inkml.NS).text
            strkList = set([])
            for t in seg.findall('ns:traceView',namespaces=Inkml.NS):
                strkList.add(t.attrib['traceDataRef'])
            self.segments[id] = Segment(id,label, strkList)

    def getTraces(self, height = 256):
        traces_array = [np.array([p.strip().split()[:2]
            for p in self.strokes[id].split(',')], dtype='float')
              for id in self.strkOrder ]

        ratio = height / ((np.concatenate(traces_array, 0).max(0) - np.concatenate(traces_array, 0).min(0))[1] + 1e-6)
        return [(trace * ratio).astype(int).tolist() for trace in traces_array]

# %% [markdown]
# `Inkml` class is used to read an inkml file and extract the strokes
#
# ***Input***: the path to the inkml file.
#
# ***Output***: Inkml object that can be used to extract the strokes.

# %% [markdown]
# #### Visualize InkML traces

# %% [markdown]
# > The coordinations of pen traces (x, y) are obtain from collection device, origin at top left position. To visualize, the y coordination need to be inverted.

# %%
import matplotlib.pyplot as plt
def visualize_inkml(ink_obj: Inkml):
    ink = ink_obj

    plt.figure(figsize=(16, 4))
    plt.axis("off")
    for trace in ink.getTraces():
        trace_arr = np.array(trace)
        plt.plot(trace_arr[:, 0], -trace_arr[:, 1])  # invert y coordinate


path = 'crohme2019/crohme2019/valid/18_em_0.inkml'
ink = Inkml(path)
visualize_inkml(ink)

# %% [markdown]
# > **TASK: UNDERSTAND AND HANDLE OUTPUT OF `getTraces()` METHOD IN `Inkml` CLASS.**

# %%
# ink object from an InkML file
ink = Inkml('crohme2019/crohme2019/valid/18_em_0.inkml')

# get traces from the ink object
[np.array(trace).shape for trace in ink.getTraces()]
# Out:
# [(525, 2),
#  (113, 2),
#  (118, 2),
#  (328, 2),
#  (350, 2),
#  (96, 2),
#  (130, 2),
#  (115, 2),
#  (293, 2),
#  (304, 2),
#  (111, 2),
#  (133, 2),
#  (265, 2),
#  (329, 2),
#  (103, 2),
#  (132, 2)]

# %% [markdown]
# **WARNING**: _Some Inkml may return (x, y, t) coordinates, while others may return (x, y) coordinates. Make sure to handle this in your implementation._

# %% [markdown]
# Now you have the idea of how to read an inkml file, let's build the Dataset class.
#
# #### Build Dataset
#
# Base on the observation, how can we build a dataset class from the dataset files?
#
# ***Hints:***
#    - *Understand the big picture. (Data --> Dataset --> DataLoader --> Model --> Output --> Calculate Loss --> Backpropagation --> Update weight)*
#    - *What do our model expect to get? In other words, what information is being fed into our model to calculate the loss?*
#    - *What informations needed to calculate our Loss?*
#    - *What should be returned in the `__getitem__` method?*
#    - *The outputs should be of Tensor type*
#
# ***References from pytorch tutorials***
#
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# torch.utils.data.Dataset is an abstract class representing a dataset. Your custom dataset should inherit Dataset and override the following methods:
#
# - \_\_len\_\_ so that len(dataset) returns the size of the dataset.
#
# - \_\_getitem\_\_ to support the indexing such that dataset[i] can be used to get ith sample.

# %% [markdown]
# > **TASK: IMPLEMENT `InkmlDataset` CLASS.**
#
# You need to complete the implementation of InkMmlDataset class. Check out the sub-tasks for more information.

# %%
from torch.utils.data import Dataset
import os
import xml.etree.ElementTree as ET
import numpy as np
import math
import torch
from rdp import rdp

class InkmlDataset(Dataset):
    def __init__(self, annotation, root_dir, vocab):
        self.annotation = annotation
        self.root_dir = root_dir
        self.vocab = vocab

        self.ink_paths = []
        self.labels = []

        with open(self.annotation, 'r') as f:
            for line in f:
                parts = line.strip().split('\t')
                if len(parts) == 2:
                    ink_file, label = parts
                    full_path = os.path.join(self.root_dir, ink_file)
                    self.ink_paths.append(full_path)
                    self.labels.append(label)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        inkfile = self.ink_paths[idx]
        label = self.labels[idx]

        traces = Inkml(inkfile).getTraces()
        traces = [remove_duplicate(trace) for trace in traces]
        
        feature = feature_extraction(traces)
        feature = torch.tensor(feature, dtype=torch.float32)

        label = [self.vocab.word2index[token] for token in label.split()]
        label = torch.tensor(label, dtype=torch.long)
        input_len = torch.tensor([feature.shape[0]], dtype=torch.long)
        label_len = torch.tensor(len(label), dtype=torch.long)

        return feature, label, input_len, label_len

# %% [markdown]
# #### Feature representation
#
# In this subtask, we will convert the strokes into feature representations that can be used by the model.
#
# Initially, the `.getTraces()` method returns list of strokes, where each stroke is a list of (x, y) coordinates. Intuitively, we can use those coordinates as features. But if we directly use the coordinates, the model will have a hard time learning the patterns.
#
# Instead, we can calculate the difference *(∆d)* between consecutive coordinates as features. This way, the model can learn the patterns more easily.
# The feature could also be normalize as ($\frac{\Delta_x}{d}$ , $\frac{\Delta_y} {d}$, $d$), where $d = \sqrt{\Delta_x^2 + \Delta_y^2}$
#
# **Pen-up and Pen-down**
#
# In the dataset, each stroke is separated by a pen-up event. We can use this information to separate the strokes.
#
# 1. The pen is lifted from the paper (connecting the end of a stroke to the start of a stroke): $pen\_up = 1$
# 2. The pen is on the paper: $pen\_up = 0$
#
# Then, our feature representation would be:
# ($\frac{\Delta_x}{d}$ , $\frac{\Delta_y} {d}$, $d$, $pen\_up$)
#
#
# ```
# point 1: (x1, y1)
# point 2: (x2, y2)
# point 3: (x3, y3) <--- end of stroke #1
# point 4: (x4, y4) <--- start of stroke #2
# ...
# point n: (xn, yn)
# ```
#
# The feature representation will be:
#
# ```
# f1 = ((x2 - x1) / d, (y2 - y1)/d, d, 0)
# f2 = ((x3 - x2) / d, (y3 - y2)/d, d, 0)
# f3 = ((x4 - x3) / d, (y4 - y3)/d, d, 1) <-- pen up
# ...
# fn-1 = ((xn - xn-1) / d, (yn - yn-1)/d, d, 0)
# ```

# %% [markdown]
# > **Subtask: REMOVE DUPLICATED POINTS.**

# %%
def remove_duplicate(trace):
    new_trace = [trace[0]] if trace else []
    for point in trace[1:]:
        if point != new_trace[-1]:
            new_trace.append(point)
    return new_trace

# %% [markdown]
# > **Test your implementation**

# %%
ink = Inkml('crohme2019/crohme2019/valid/18_em_0.inkml')
traces = ink.getTraces()
traces = [remove_duplicate(trace) for trace in traces]

assert list(map(len,traces)) == [82, 16, 21, 78, 82, 15, 18, 18, 28, 58, 15, 19, 56, 70, 18, 21]

# %% [markdown]
# > **Subtask: CALCULATE `(∆X / d, ∆Y /d, d)` FOR INPUT FEATURE.**

# %%
import math
def feature_extraction (traces):
    features = []
    last_point = None
    for stroke in traces:
        if len(stroke) < 2:  # Check if stroke has less than 2 points
            continue
        
        if last_point is not None:
            x1, y1 = last_point
            x2, y2 = stroke[0]
            dx = x2 - x1
            dy = y2 - y1
            d = math.sqrt(dx**2 + dy**2)
            
            if d > 0:
                normalized_feature = (dx / d, dy / d, d)
            else:
                normalized_feature = (0, 0, 0)
            features.append(normalized_feature)
        
        for i in range(1, len(stroke)):
            x_prev, y_prev = stroke[i-1]
            x_curr, y_curr = stroke[i]
            delta_x = x_curr - x_prev
            delta_y = y_curr - y_prev
            d = math.sqrt(delta_x**2 + delta_y**2)
            if d > 0:
                normalized_feature = (delta_x / d, delta_y / d, d)  
            else:
                normalized_feature = (0, 0, 0)  # Default value for points that are too close
            features.append(normalized_feature)
        last_point = stroke[-1]
        
    features_array = np.array(features)
    return features_array

# %% [markdown]
# > **Test your implementation**

# %%
ink = Inkml('crohme2019/crohme2019/valid/18_em_0.inkml')
traces = ink.getTraces()
traces = [remove_duplicate(trace) for trace in traces]
feature = feature_extraction(traces)

import numpy.testing as npt
assert feature.shape == (614, 3)
npt.assert_allclose(feature.mean(axis=0), np.array([ 0.17677799,  0.29519369, 11.35540311]))
npt.assert_allclose(feature.var(axis=0), np.array([3.75390418e-01, 5.06219812e-01, 4.19017361e+02])
)

# %% [markdown]
# > **Subtask: CALCULATE `(∆X / d, ∆Y /d, d, pen_up)` FOR INPUT FEATURE.**

# %%
def feature_extraction(traces):
    features = []
    last_point = None  # Variable to keep track of the last point in the current stroke
    
    for stroke in traces:
        if len(stroke) == 0:
            continue  # Skip empty strokes
        
        if last_point is not None:
            # Connect the last point of the previous stroke with the first point of the current stroke
            if len(last_point) != 2 or len(stroke[0]) != 2:
                continue  # Skip points that do not have exactly two values (x, y)
            
            x1, y1 = last_point
            x2, y2 = stroke[0]
            dx = x2 - x1
            dy = y2 - y1
            distance = (dx**2 + dy**2)**0.5
            pen_up = 1
            
            if distance != 0:
                features.append([dx / distance, dy / distance, distance, pen_up])
        
        for i in range(1, len(stroke)):
            if len(stroke[i - 1]) != 2 or len(stroke[i]) != 2:
                continue  # Skip points that do not have exactly two values (x, y)
            
            x1, y1 = stroke[i - 1]
            x2, y2 = stroke[i]
            dx = x2 - x1
            dy = y2 - y1
            distance = (dx**2 + dy**2)**0.5
            pen_up = 0
            
            if distance != 0:
                features.append([dx / distance, dy / distance, distance, pen_up])
        
        # Update last_point to be the last point of the current stroke
        last_point = stroke[-1]
    
    return np.array(features)

# %% [markdown]
# > **Test your implementation**

# %%
ink = Inkml('crohme2019/crohme2019/valid/18_em_0.inkml')
traces = ink.getTraces()
traces = [remove_duplicate(trace) for trace in traces]
feature = feature_extraction(traces)

import numpy.testing as npt
assert feature.shape == (614, 4)
npt.assert_array_equal(np.where(feature[:,3] == 1)[0], np.array([ 81,  97, 118, 196, 278, 293, 311, 329, 357, 415, 430, 449, 505,
       575, 593]))

# %% [markdown]
# > **Subtask: COMPLETE InkmlDataset class**
#
# From the sub-tasks, complete the implementation of InkmlDataset class.

# %% [markdown]
# > **Test your implementation**

# %%
dataset = InkmlDataset(annotation='crohme2019_valid.txt', root_dir='crohme2019', vocab=Vocab('crohme_vocab.txt'))
feature, label, input_len, label_len = dataset.__getitem__(0)

import numpy.testing as npt

assert type(feature) == torch.Tensor
assert type(label) == torch.Tensor
assert feature.shape == (231, 4)
npt.assert_array_equal(label, np.array([59, 105, 1, 105, 59, 105, 1, 105, 87, 105, 2, 105, 2]))
assert input_len == 231
assert label_len == 13

# %% [markdown]
# ### Dataloader
#
# Write the dataloader with custom collate function to pad the input and target sequence
#
# Reference:
# https://colab.research.google.com/drive/1TS7kIuNwYIN2dYGIzm-60hPnmYxKi-VN?usp=sharing
# https://plainenglish.io/blog/understanding-collate-fn-in-pytorch-f9d1742647d3

# %%
import torch
from torch.nn.utils.rnn import pad_sequence

def collate_fn(batch):
    """Create batch"""
    # your code here
    # features, labels, input_lens, label_lens should be torch.tensor
    features = [item[0] for item in batch]
    labels = [item[1] for item in batch]
    input_lens = [item[2] for item in batch]
    label_lens = [item[3] for item in batch]

    features = pad_sequence(features, batch_first=True)
    labels = pad_sequence(labels, batch_first=True)

    input_lens = torch.tensor(input_lens)
    label_lens = torch.tensor(label_lens)

    return features, labels, input_lens, label_lens

# %%
features, labels, input_lens, label_lens = collate_fn([dataset[0], dataset[1]])

import numpy.testing as npt

assert type(input_lens) == torch.Tensor
assert type(label_lens) == torch.Tensor

assert features.shape == (2, 231, 4)
assert labels.shape == (2, 13)
npt.assert_array_equal(input_lens.numpy(), np.array([231, 102]))
npt.assert_array_equal(label_lens, np.array([13, 5]))

# %%
# test collate_fn with data loader
from torch.utils.data import DataLoader
data_loader = DataLoader(dataset, batch_size=2, shuffle=False, collate_fn=collate_fn)

features, labels, input_lens, label_lens = next(iter(data_loader))
assert features.shape == (2, 231, 4)
assert labels.shape == (2, 13)
npt.assert_array_equal(input_lens.numpy(), np.array([231, 102]))
npt.assert_array_equal(label_lens, np.array([13, 5]))

# %% [markdown]
# ### Pytorch lightning datamodule

# %% [markdown]
# https://lightning.ai/docs/pytorch/stable/data/datamodule.html

# %% [markdown]
# #### Data module

# %%
from torch.utils.data import Dataset
import os
import xml.etree.ElementTree as ET
import numpy as np
import math
import torch
from rdp import rdp

class CROHME(Dataset):
    def __init__(self, annotation, root_dir, vocab, rdp=False):
        self.annotation = annotation
        self.root_dir = root_dir
        self.vocab = vocab
        self.rdp = rdp

        self.ink_paths = []
        self.labels = []

        with open(self.annotation, 'r') as f:
            for line in f:
                parts = line.strip().split('\t')
                if len(parts) == 2:
                    ink_file, label = parts
                    full_path = os.path.join(self.root_dir, ink_file)
                    self.ink_paths.append(full_path)
                    self.labels.append(label)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        inkfile = self.ink_paths[idx]
        label = self.labels[idx]

        traces = Inkml(inkfile).getTraces()
        traces = [remove_duplicate(trace) for trace in traces]
        
        if rdp:
            traces = [rdp(trace, epsilon=1) for trace in traces]

        feature = feature_extraction(traces)
        feature = torch.tensor(feature, dtype=torch.float32)

        label = [self.vocab.word2index[token] for token in label.split()]
        label = torch.tensor(label, dtype=torch.long)
        input_len = torch.tensor([feature.shape[0]], dtype=torch.long)
        label_len = torch.tensor(len(label), dtype=torch.long)

        return feature, label, input_len, label_len

# %%
import pytorch_lightning as pl
from torch.utils.data import DataLoader

class CROHMEDatamodule(pl.LightningDataModule):
    def __init__(self, root_dir, train_annotation, validation_annotation, test_annotation, vocab_file, batch_size):
        super().__init__()
        self.root_dir = root_dir
        self.batch_size = batch_size
        self.train_annotation = train_annotation
        self.validation_annotation = validation_annotation
        self.test_annotation = test_annotation
        self.vocab = Vocab(vocab_file)

    def setup(self, stage: str = None):
        self.train_dataset = CROHME(self.train_annotation, self.root_dir, self.vocab, rdp=True)  # Assuming CROHME is defined elsewhere
        self.val_dataset = CROHME(self.validation_annotation, self.root_dir, self.vocab)
        self.test_dataset = CROHME(self.test_annotation, self.root_dir, self.vocab)

    def train_dataloader(self):
        return DataLoader(self.train_dataset, batch_size=self.batch_size, shuffle=True, collate_fn=collate_fn)  # Assuming collate_fn is defined elsewhere

    def val_dataloader(self):
        return DataLoader(self.val_dataset, batch_size=self.batch_size, shuffle=False, collate_fn=collate_fn)

    def test_dataloader(self):
        return DataLoader(self.test_dataset, batch_size=self.batch_size, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# ## Model

# %% [markdown]
# Check out this tutorial
# https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html

# %%
# build a model of Bidirectional LSTM 3 x 128
import torch.nn as nn
class LSTM_TemporalClassification(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        # declare layers
        super(LSTM_TemporalClassification, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        # write calculation process here
        output, _ = self.lstm(x)
        x = self.fc(output)

        return x

# %%
# test your implementation
model = LSTM_TemporalClassification(4, 128, 3, 109)
assert model.forward(torch.rand((10, 100, 4))).shape == (10, 100, 109)

# %% [markdown]
# ### Loss: CTC

# %% [markdown]
# Read the documentation of CTC loss
# https://pytorch.org/docs/stable/generated/torch.nn.CTCLoss.html
#
# What is the role of `input_lengths`, `target_lengths`
#
# ```
# loss = nn.CTCLoss()(input, target, input_lengths, target_lengths)
# ```

# %% [markdown]
# ### Pytorch lightning Module
#
# https://lightning.ai/docs/pytorch/stable/common/lightning_module.html
#
# A LightningModule organizes your PyTorch code into 6 sections:
#
# Initialization (\_\_init\_\_ and setup()).
#
# Train Loop (training_step())
#
# Validation Loop (validation_step())
#
# Test Loop (test_step())
#
# Prediction Loop (predict_step())
#
# Optimizers and LR Schedulers (configure_optimizers())
#
# An example of a LightningModule

# %% [markdown]
# > **Task: Complete the LightningModule**
#
# - Calculate loss
# - Log the loss

# %%
import pytorch_lightning as pl
import torch

class MathOnlineModel(pl.LightningModule):
    def __init__(self, lr=0.001, input_size=4, output_size=109, hidden_size=128, num_layers = 3, decoder=None):
        super().__init__()
        self.model = LSTM_TemporalClassification(input_size, hidden_size, num_layers, output_size)
        self.criterion = nn.CTCLoss(blank=output_size - 1)
        self.lr = lr
        self.decoder = decoder

    def forward(self, x):
        return self.model(x)
    def training_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        loss = self.criterion(y_hat.log_softmax(2), y, x_lens, y_lens)

        self.log('train_loss', loss, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        loss = self.criterion(y_hat.log_softmax(2), y, x_lens, y_lens)

        self.log('val_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def test_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch
        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        loss = self.criterion(y_hat.log_softmax(2), y, x_lens, y_lens)

        self.log('test_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=self.lr)

# %% [markdown]
# ## Trainer (pytorch lightning)

# %% [markdown]
# Pytorch lightning trainer:
# https://lightning.ai/docs/pytorch/stable/common/trainer.html
#
# From the documentation:
#
# > The Lightning Trainer does much more than just “training”. Under the hood, it handles all loop details for you, some examples include:
# > - Automatically enabling/disabling grads
# > - Running the training, validation and test dataloaders
# > - Calling the Callbacks at the appropriate times
# > - Putting batches and computations on the correct devices

# %%
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning import Trainer

trainer = Trainer(
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=3, mode='min'),
        LearningRateMonitor(logging_interval='step'),
        ModelCheckpoint(filename='{epoch}-{val_loss:.4f}-rdp', save_top_k=3, monitor='val_loss', mode='min'),
    ],
    logger = TensorBoardLogger('lightning_logs'),
    check_val_every_n_epoch=1,
    fast_dev_run=False,
    default_root_dir='checkpoint',
    deterministic=False,
    max_epochs=30,
    log_every_n_steps=50,
    devices = 1,
)
model = MathOnlineModel()
# model = MathOnlineModel.load_from_checkpoint('lightning_logs/lightning_logs/version_18/checkpoints/epoch=9-val_loss=2.0883-rdp.ckpt')

dm = CROHMEDatamodule(root_dir='crohme2019',
                       train_annotation='crohme2019_train.txt',
                       validation_annotation='crohme2019_valid.txt',
                       test_annotation='crohme2019_test.txt',
                       vocab_file='crohme_vocab.txt',
                       batch_size=1
                     )

trainer.fit(model, dm)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                        | Params | Mode
# ------------------------------------------------------------------
# 0 | model     | LSTM_TemporalClassification | 955 K  | train
# 1 | criterion | CTCLoss                     | 0      | train
# ------------------------------------------------------------------
# 955 K     Trainable params
# 0         Non-trainable params
# 955 K     Total params
# 3.823     Total estimated model params size (MB)
# c:\Users\tinvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# c:\Users\tinvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 9:  12%|█▏        | 1065/8900 [14:13<1:44:40,  1.25it/s, v_num=19, train_loss_step=0.210, val_loss=0.930, train_loss_epoch=0.201]
# Epoch 10:   2%|▏         | 156/8900 [00:09<09:09, 15.92it/s, v_num=15, train_loss_step=0.859, val_loss=0.629, train_loss_epoch=0.270]
# c:\Users\tinvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...

# %% [markdown]
# **Tips on training:**
# - Debug with **fast_dev_run**:
# Before run the training process, it is better to make a quick check of training and validation loop. Set fast_dev_run=True, then run the trainer and check if there is any bug exist.
# - Training initially with **small batch size**:
# In practice, training with CTC loss converges slowly for large batch size. To accelerate convergence, training with small batch size first, save model, then, train with large batch size.

# %% [markdown]
# #### Inference
#
# The output of networks need to process by a decoding step.
#
# - Greedy decode: Your task is to implement greedy decoding method. Which converts the output into a string of symbols and relations (same form with labels). Greedy decoder produce the best path by removing consecutive repeated symbols/relations and then remove \<blank\>
#
# **Your task**
# Based on GreedyCTCDecoder class from the following link, write decoding for an output.
# https://pytorch.org/audio/main/tutorials/asr_inference_with_ctc_decoder_tutorial.html#greedy-decoder

# %%
from typing import List
import torch
class GreedyCTCDecoder(torch.nn.Module):
    def __init__(self, vocab):
        super().__init__()
        self.vocab = vocab
        self.blank = vocab.word2index['<blank>']

    def forward(self, emission: torch.Tensor) -> List[str]:
        """Given a sequence emission over labels, get the best path
        Args:
          emission (Tensor): Logit tensors. Shape `[seq_len, num_label]`.

        Returns:
          List[str]: The resulting transcript
        """
        # your implementation
         # Step 1: Get the most probable labels for each time step
        indices = torch.argmax(emission, dim=-1)

        # Step 2 & 3: Remove consecutive duplicates and blanks
        decoded_sequence = []
        prev_index = None
        for index in indices:
            if index != prev_index and index != self.blank:  # Check for non-duplicates and non-blank
                decoded_sequence.append(index.item())
            prev_index = index

        # Step 4: Convert indices to characters using the vocabulary
        output_seq_list = [self.vocab.index2word[index] for index in decoded_sequence]
        return output_seq_list

# %%
# test code
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MathOnlineModel.load_from_checkpoint('lightning_logs/lightning_logs/version_15/checkpoints/epoch=7-val_wer=0.2442.ckpt')
model = model.to(device)
model.eval()

dataset = InkmlDataset(annotation='crohme2019_valid.txt', root_dir='crohme2019', vocab=Vocab('crohme_vocab.txt'))
feature, label, input_len, label_len = dataset.__getitem__(0)
greedy_decoder = GreedyCTCDecoder(vocab)

# run model forward with feature --> output
feature = feature.unsqueeze(0).to(device)
output = model(feature)

# run greedy decoder
decoded = greedy_decoder(output[0])
print(decoded)

# possible output if your training work well
# decoded -> ['\\phi', 'Right', '(', 'Right', '0', 'Right', '(', 'Right', 'n', 'Right', ')', 'Right', ')']
# Out:
# ['Right', '(', 'Right', '\\phi', 'Right', '(', 'Right', 'n', 'Right', ')', 'NoRel', ')']

# %% [markdown]
# #### Add calulation of metrics (accuracy, loss) during validation and test
#
# - Edit distance: calculate edit distance between output and target.

# %% [markdown]
# > **Sub-task: Calculate edit distance between two list of tokens**

# %%
from torchmetrics.functional.text.helper import _LevenshteinEditDistance

def edit_distance(pred_seq, label_seq):
    # Your code here    
    leven = _LevenshteinEditDistance(label_seq)
    distance, _ = leven(pred_seq)
    
    return distance

# Test your implementation
assert edit_distance(['\\phi',
  'Right',
  '(',
  'Right',
  '0',
  'Right',
  '(',
  'Right',
  'n',
  'Right',
  ')',
  'Right',
  ')'],
 ['\\phi',
  'Right',
  '(',
  'Right',
  '\\phi',
  'Right',
  '(',
  'Right',
  'n',
  'Right',
  ')',
  'Right',
  ')']) == 1

# %% [markdown]
# **Add word error rate (wer) metric to the model**

# %%
greedy_decoder = GreedyCTCDecoder(vocab)

# %%
import pytorch_lightning as pl
import torch
from torchmetrics.functional.text.helper import _LevenshteinEditDistance as _LE_distance

class MathOnlineModel(pl.LightningModule):
    def __init__(self, lr=0.001, input_size=4, output_size=109, hidden_size=128, num_layers = 3, decoder=greedy_decoder):
        super().__init__()
        self.model = LSTM_TemporalClassification(input_size, hidden_size, num_layers, output_size)
        self.criterion = nn.CTCLoss(blank=output_size - 1)
        self.lr = lr
        self.decoder = decoder

    def forward(self, x):
        return self.model(x)
    
    def training_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)

        self.log('train_loss', loss, prog_bar=True, on_step=True, on_epoch=True)
        self.log('train_wer', total_edits / total_lens, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)

        self.log('val_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('val_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def test_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)
            
        self.log('test_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('test_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=self.lr)

# %%
# import pytorch_lightning as pl
# import torch
# from torchmetrics.functional.text.helper import _LevenshteinEditDistance as _LE_distance

# class MathOnlineModel(pl.LightningModule):
#     def __init__(self, lr=0.001, input_size=4, output_size=109, hidden_size=128, num_layers = 3, decoder=None):
#         super().__init__()
#         self.model = LSTM_TemporalClassification(input_size, hidden_size, num_layers, output_size)
#         self.criterion = nn.CTCLoss(blank=output_size - 1)
#         self.lr = lr
#         self.decoder = decoder
#         self.vocab=Vocab('crohme_vocab.txt')
        
#     def forward(self, x):
#         return self.model(x)
#     def training_step(self, batch, batch_idx):
#         x, y, x_lens, y_lens = batch
#         # Forward pass
#         logits = self.model(x)
#         log_probs = torch.nn.functional.log_softmax(logits, dim=2)
#         # your code to calculate loss
#         y_hat = self.model(x)
#         y_hat = y_hat.permute(1, 0, 2)
#         loss = self.criterion(y_hat.log_softmax(2), y, x_lens, y_lens)

#         # your code to calculate total edit distance
#         total_edits = 0
#         total_lens = 0
#         for i in range(len(y)):
#             with torch.no_grad():
#                 decoded = self.decoder(log_probs[i])
#             pred_seq = decoded
#             label_seq = [self.vocab.index2word[y[i][j].item()] for j in range(y_lens[i])]  # Convert indices to words
#             edit_distances = edit_distance(pred_seq, label_seq)

#         # loop: calculate edit distance
#             total_edits += edit_distances
#             total_lens += y_lens[i]
            
#         self.log('train_loss', loss, prog_bar=True, on_step=True, on_epoch=True)
#         self.log('train_wer', total_edits / total_lens, prog_bar=True, on_step=True, on_epoch=True)
#         return loss
    
#     def validation_step(self, batch, batch_idx):
#         x, y, x_lens, y_lens = batch
#         # Forward pass
#         logits = self.model(x)
#         log_probs = torch.nn.functional.log_softmax(logits, dim=-1)
#         # your code to calculate loss
#         y_hat = self.model(x)
#         y_hat = y_hat.permute(1, 0, 2)
#         loss = self.criterion(y_hat.log_softmax(2), y, x_lens, y_lens)
        
#         # your code to calculate total edit distance
#         total_edits = 0
#         total_lens = 0
#         for i in range(len(y)):
#             with torch.no_grad():
#                 decoded = self.decoder(log_probs[i])
#             pred_seq = decoded
#             label_seq = [self.vocab.index2word[y[i][j].item()] for j in range(y_lens[i])]  # Convert indices to words
#             edit_distances = edit_distance(pred_seq, label_seq)

#         # loop: calculate edit distance
#             total_edits += edit_distances
#             total_lens += y_lens[i]
        
#         self.log('val_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
#         self.log('val_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
#         return loss
    
#     def test_step(self, batch, batch_idx):
#         x, y, x_lens, y_lens = batch
#         # Forward pass
#         logits = self.model(x)
#         log_probs = torch.nn.functional.log_softmax(logits, dim=-1)
#         # your code to calculate loss
#         y_hat = self.model(x)
#         y_hat = y_hat.permute(1, 0, 2)
#         loss = self.criterion(y_hat.log_softmax(2), y, x_lens, y_lens)

#         # your code to calculate total edit distance
#         total_edits = 0
#         total_lens = 0
#         for i in range(len(y)):
#             with torch.no_grad():
#                 decoded = self.decoder(log_probs[i])
#             pred_seq = decoded
#             label_seq = [self.vocab.index2word[y[i][j].item()] for j in range(y_lens[i])]  # Convert indices to words
#             edit_distances = edit_distance(pred_seq, label_seq)

#         # loop: calculate edit distance
#             total_edits += edit_distances
#             total_lens += y_lens[i]
        
#         self.log('test_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
#         self.log('test_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
#         return loss

#     def configure_optimizers(self):
#         return torch.optim.Adam(self.model.parameters(), lr=self.lr)

# %% [markdown]
# **Continue to train the model**
#
# - Load the latest trained model:
#
# ```
# model = MathOnlineModel.load_from_checkpoint('path/to/your/checkpoint.ckpt')
# ```
# - Change config of ModelCheckPoint to monitor the new metric (val_wer) instead.
#
# ```
#         ModelCheckpoint(filename='{epoch}-{val_loss:.4f}', save_top_k=5, monitor='val_loss', mode='min')
#
#       --> ModelCheckpoint(filename='{epoch}-{val_wer:.4f}', save_top_k=5, monitor='val_wer', mode='min'),
#
# ```

# %%
torch.set_float32_matmul_precision("highest")

# %%
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning import Trainer

trainer = Trainer(
    callbacks = [
        EarlyStopping(monitor='val_wer', patience=5, mode='min'),
        LearningRateMonitor(logging_interval='step'),
        ModelCheckpoint(filename='{epoch}-{val_wer:.4f}', save_top_k=2, monitor='val_wer', mode='min'),
    ],
    logger = TensorBoardLogger('lightning_logs'),
    check_val_every_n_epoch=1,
    fast_dev_run=False,
    default_root_dir='checkpoint',
    deterministic=False,
    max_epochs=20,
    log_every_n_steps=50,
    devices = 1
)
# model = MathOnlineModel(decoder=greedy_decoder)
model = MathOnlineModel.load_from_checkpoint('lightning_logs/lightning_logs/version_16/checkpoints/epoch=7-val_wer=0.1708.ckpt')

dm = CROHMEDatamodule(root_dir='crohme2019',
                       train_annotation='crohme2019_train.txt',
                       validation_annotation='crohme2019_valid.txt',
                       test_annotation='crohme2019_test.txt',
                       vocab_file='crohme_vocab.txt',
                       batch_size=1
                    )

trainer.fit(model, dm)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce MX570') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                        | Params | Mode
# ------------------------------------------------------------------
# 0 | model     | LSTM_TemporalClassification | 955 K  | train
# 1 | criterion | CTCLoss                     | 0      | train
# 2 | decoder   | GreedyCTCDecoder            | 0      | train
# ------------------------------------------------------------------
# 955 K     Trainable params
# 0         Non-trainable params
# 955 K     Total params
# 3.823     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# c:\Users\tinvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# c:\Users\tinvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 5:  74%|███████▍  | 6601/8900 [20:50<07:15,  5.28it/s, v_num=17, train_loss_step=0.331, train_wer_step=0.0952, val_loss=0.730, val_wer=0.176, train_loss_epoch=0.128, train_wer_epoch=0.0405]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Bonus 1 (+1 pts for final exam)
#
# Add metrics to evaluate accuracy of symbols and relations separately

# %%
#'Above': 101, 'Below': 102, 'Inside': 103, 'NoRel': 104, 'Right': 105, 'Sub': 106, 'Sup': 107
vocab_dict = vocab.word2index
relation = ['Above', 'Below', 'Inside', 'NoRel', 'Right', 'Sub', 'Sup']
relation_idx = [vocab_dict[rel] for rel in relation]

# %%
import pytorch_lightning as pl
import torch
from torchmetrics.functional.text.helper import _LevenshteinEditDistance as _LE_distance

class MathOnlineModel2(pl.LightningModule):
    def __init__(self, lr=0.001, input_size=4, output_size=109, hidden_size=128, num_layers = 3, decoder=greedy_decoder):
        super().__init__()
        self.model = LSTM_TemporalClassification(input_size, hidden_size, num_layers, output_size)
        self.criterion = nn.CTCLoss(blank=output_size - 1)
        self.lr = lr
        self.decoder = decoder

    def forward(self, x):
        return self.model(x)
    
    def training_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)

        self.log('train_loss', loss, prog_bar=True, on_step=True, on_epoch=True)
        self.log('train_wer', total_edits / total_lens, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            print()
            # print("Pred seq:", pred_seq)
            # print("Label seq:", label_seq)
            
            relation_pred = [rel for rel in pred_seq if rel in relation]
            symbol_pred = [rel for rel in pred_seq if rel not in relation]
            # print("Relation pred:", relation_pred)
            # print("Symbol pred:", symbol_pred)
            
            relation_label = [rel for rel in label_seq if rel in relation]
            symbol_label = [rel for rel in label_seq if rel not in relation]
            # print("Relation label:", relation_label)
            # print("Symbol label:", symbol_label)
            
            relation_edit = edit_distance(relation_pred, relation_label)
            relation_lens = len(relation_label)
            
            symbol_edit = edit_distance(symbol_pred, symbol_label)
            symbol_lens = len(symbol_label)        
            
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)

        self.log('val_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('val_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
        
        if relation_lens > 0:
            self.log('val_wer_relation', relation_edit / relation_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('val_wer_relation', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        if symbol_lens > 0:
            self.log('val_wer_symbol', symbol_edit / symbol_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('val_wer_symbol', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        return loss

    def test_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            print()
            # print("Pred seq:", pred_seq)
            # print("Label seq:", label_seq)
            
            relation_pred = [rel for rel in pred_seq if rel in relation]
            symbol_pred = [rel for rel in pred_seq if rel not in relation]
            # print("Relation pred:", relation_pred)
            # print("Symbol pred:", symbol_pred)
            
            relation_label = [rel for rel in label_seq if rel in relation]
            symbol_label = [rel for rel in label_seq if rel not in relation]
            # print("Relation label:", relation_label)
            # print("Symbol label:", symbol_label)
            
            relation_edit = edit_distance(relation_pred, relation_label)
            relation_lens = len(relation_label)
            
            symbol_edit = edit_distance(symbol_pred, symbol_label)
            symbol_lens = len(symbol_label)        
            
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)
            
        
        self.log('test_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('test_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
        
        if relation_lens > 0:
            self.log('test_wer_relation', relation_edit / relation_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('test_wer_relation', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        if symbol_lens > 0:
            self.log('test_wer_symbol', symbol_edit / symbol_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('test_wer_symbol', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=self.lr)

# %%
# run test on validation dataset
# load your best val_wer model

from pytorch_lightning import Trainer

trainer = Trainer(
    devices = 1,
)

# Load the model from a checkpoint
model = MathOnlineModel2.load_from_checkpoint(
    'lightning_logs/lightning_logs/version_14/checkpoints/epoch=11-val_wer=0.1422.ckpt', 
    decoder=GreedyCTCDecoder(dataset.vocab)
)

# Initialize the data module
dm = CROHMEDatamodule(
    root_dir='crohme2019', 
    train_annotation='crohme2019_train.txt', 
    validation_annotation='crohme2019_valid.txt', 
    test_annotation='crohme2019_valid.txt', 
    vocab_file='crohme_vocab.txt', 
    batch_size=1
)

# Test the model
trainer.test(model, datamodule=dm)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\tinvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Testing DataLoader 0:   0%|          | 0/986 [00:00<?, ?it/s]0
#
# Testing DataLoader 0:   0%|          | 1/986 [00:00<02:24,  6.81it/s]0
#
# Testing DataLoader 0:   0%|          | 2/986 [00:00<01:48,  9.04it/s]0
#
# Testing DataLoader 0:   0%|          | 3/986 [00:00<01:58,  8.30it/s]0
#
# Testing DataLoader 0:   0%|          | 4/986 [00:00<02:09,  7.56it/s]0
#
# Testing DataLoader 0:   1%|          | 5/986 [00:00<02:36,  6.27it/s]0
#
# Testing DataLoader 0:   1%|          | 6/986 [00:00<02:42,  6.04it/s]0
#
# Testing DataLoader 0:   1%|          | 7/986 [00:01<02:36,  6.26it/s]0
#
# Testing DataLoader 0:   1%|          | 8/986 [00:01<02:48,  5.80it/s]0
#
# Testing DataLoader 0:   1%|          | 9/986 [00:01<02:48,  5.81it/s]0
#
# Testing DataLoader 0:   1%|          | 10/986 [00:02<03:19,  4.89it/s]0
#
# Testing DataLoader 0:   1%|          | 11/986 [00:02<03:22,  4.83it/s]0
#
# Testing DataLoader 0:   1%|          | 12/986 [00:02<03:40,  4.42it/s]0
#
# Testing DataLoader 0:   1%|▏         | 13/986 [00:02<03:28,  4.67it/s]0
#
# Testing DataLoader 0:   1%|▏         | 14/986 [00:02<03:24,  4.75it/s]0
#
# Testing DataLoader 0:   2%|▏         | 15/986 [00:03<03:28,  4.65it/s]0
#
# Testing DataLoader 0:   2%|▏         | 16/986 [00:03<03:27,  4.68it/s]0
#
# Testing DataLoader 0:   2%|▏         | 17/986 [00:03<03:31,  4.58it/s]0
#
# Testing DataLoader 0:   2%|▏         | 18/986 [00:03<03:29,  4.62it/s]0
#
# Testing DataLoader 0:   2%|▏         | 19/986 [00:04<03:36,  4.47it/s]0
#
# Testing DataLoader 0:   2%|▏         | 20/986 [00:04<03:34,  4.50it/s]0
#
# Testing DataLoader 0:   2%|▏         | 21/986 [00:04<03:31,  4.57it/s]0
#
# Testing DataLoader 0:   2%|▏         | 22/986 [00:04<03:30,  4.58it/s]0
#
# Testing DataLoader 0:   2%|▏         | 23/986 [00:04<03:26,  4.66it/s]0
#
# Testing DataLoader 0:   2%|▏         | 24/986 [00:05<03:21,  4.77it/s]0
#
# Testing DataLoader 0:   3%|▎         | 25/986 [00:05<03:15,  4.91it/s]0
#
# Testing DataLoader 0:   3%|▎         | 26/986 [00:05<03:18,  4.85it/s]0
#
# Testing DataLoader 0:   3%|▎         | 27/986 [00:05<03:13,  4.96it/s]0
#
# Testing DataLoader 0:   3%|▎         | 28/986 [00:05<03:12,  4.98it/s]0
#
# Testing DataLoader 0:   3%|▎         | 29/986 [00:05<03:08,  5.07it/s]0
#
# Testing DataLoader 0:   3%|▎         | 30/986 [00:05<03:03,  5.20it/s]0
#
# Testing DataLoader 0:   3%|▎         | 31/986 [00:05<03:01,  5.25it/s]0
#
# Testing DataLoader 0:   3%|▎         | 32/986 [00:05<02:58,  5.34it/s]0
#
# Testing DataLoader 0:   3%|▎         | 33/986 [00:06<02:58,  5.34it/s]0
#
# Testing DataLoader 0:   3%|▎         | 34/986 [00:06<02:55,  5.43it/s]0
#
# Testing DataLoader 0:   4%|▎         | 35/986 [00:06<02:53,  5.47it/s]0
#
# Testing DataLoader 0:   4%|▎         | 36/986 [00:06<02:50,  5.57it/s]0
#
# Testing DataLoader 0:   4%|▍         | 37/986 [00:06<02:50,  5.57it/s]0
#
# Testing DataLoader 0:   4%|▍         | 38/986 [00:06<02:52,  5.51it/s]0
#
# Testing DataLoader 0:   4%|▍         | 39/986 [00:06<02:49,  5.57it/s]0
#
# Testing DataLoader 0:   4%|▍         | 40/986 [00:07<02:49,  5.57it/s]0
#
# Testing DataLoader 0:   4%|▍         | 41/986 [00:07<02:47,  5.63it/s]0
#
# Testing DataLoader 0:   4%|▍         | 42/986 [00:07<02:49,  5.57it/s]0
#
# Testing DataLoader 0:   4%|▍         | 43/986 [00:07<02:46,  5.67it/s]0
#
# Testing DataLoader 0:   4%|▍         | 44/986 [00:07<02:45,  5.70it/s]0
#
# Testing DataLoader 0:   5%|▍         | 45/986 [00:08<02:49,  5.57it/s]0
#
# Testing DataLoader 0:   5%|▍         | 46/986 [00:08<02:47,  5.60it/s]0
#
# Testing DataLoader 0:   5%|▍         | 47/986 [00:08<02:46,  5.63it/s]0
#
# Testing DataLoader 0:   5%|▍         | 48/986 [00:08<02:44,  5.69it/s]0
#
# Testing DataLoader 0:   5%|▍         | 49/986 [00:08<02:43,  5.72it/s]0
#
# Testing DataLoader 0:   5%|▌         | 50/986 [00:08<02:41,  5.78it/s]0
#
# Testing DataLoader 0:   5%|▌         | 51/986 [00:08<02:40,  5.81it/s]0
#
# Testing DataLoader 0:   5%|▌         | 52/986 [00:08<02:38,  5.88it/s]0
#
# Testing DataLoader 0:   5%|▌         | 53/986 [00:09<02:40,  5.81it/s]0
#
# Testing DataLoader 0:   5%|▌         | 54/986 [00:09<02:40,  5.80it/s]0
#
# Testing DataLoader 0:   6%|▌         | 55/986 [00:09<02:40,  5.81it/s]0
#
# Testing DataLoader 0:   6%|▌         | 56/986 [00:09<02:42,  5.72it/s]0
#
# Testing DataLoader 0:   6%|▌         | 57/986 [00:09<02:40,  5.79it/s]0
#
# Testing DataLoader 0:   6%|▌         | 58/986 [00:09<02:39,  5.82it/s]0
#
# Testing DataLoader 0:   6%|▌         | 59/986 [00:10<02:37,  5.87it/s]0
#
# Testing DataLoader 0:   6%|▌         | 60/986 [00:10<02:36,  5.93it/s]0
#
# Testing DataLoader 0:   6%|▌         | 61/986 [00:10<02:35,  5.93it/s]0
#
# Testing DataLoader 0:   6%|▋         | 62/986 [00:10<02:34,  5.98it/s]0
#
# Testing DataLoader 0:   6%|▋         | 63/986 [00:10<02:34,  5.98it/s]0
#
# Testing DataLoader 0:   6%|▋         | 64/986 [00:10<02:33,  6.01it/s]0
#
# Testing DataLoader 0:   7%|▋         | 65/986 [00:10<02:33,  6.01it/s]0
#
# Testing DataLoader 0:   7%|▋         | 66/986 [00:11<02:34,  5.96it/s]0
#
# Testing DataLoader 0:   7%|▋         | 67/986 [00:11<02:34,  5.96it/s]0
#
# Testing DataLoader 0:   7%|▋         | 68/986 [00:11<02:33,  5.99it/s]0
#
# Testing DataLoader 0:   7%|▋         | 69/986 [00:11<02:31,  6.04it/s]0
#
# Testing DataLoader 0:   7%|▋         | 70/986 [00:11<02:32,  6.00it/s]0
#
# Testing DataLoader 0:   7%|▋         | 71/986 [00:11<02:31,  6.04it/s]0
#
# Testing DataLoader 0:   7%|▋         | 72/986 [00:11<02:30,  6.09it/s]0
#
# Testing DataLoader 0:   7%|▋         | 73/986 [00:11<02:29,  6.09it/s]0
#
# Testing DataLoader 0:   8%|▊         | 74/986 [00:12<02:28,  6.13it/s]0
#
# Testing DataLoader 0:   8%|▊         | 75/986 [00:12<02:28,  6.14it/s]0
#
# Testing DataLoader 0:   8%|▊         | 76/986 [00:12<02:26,  6.20it/s]0
#
# Testing DataLoader 0:   8%|▊         | 77/986 [00:12<02:29,  6.06it/s]0
#
# Testing DataLoader 0:   8%|▊         | 78/986 [00:13<02:32,  5.96it/s]0
#
# Testing DataLoader 0:   8%|▊         | 79/986 [00:13<02:31,  5.99it/s]0
#
# Testing DataLoader 0:   8%|▊         | 80/986 [00:13<02:30,  6.00it/s]0
#
# Testing DataLoader 0:   8%|▊         | 81/986 [00:13<02:34,  5.85it/s]0
#
# Testing DataLoader 0:   8%|▊         | 82/986 [00:14<02:34,  5.84it/s]0
#
# Testing DataLoader 0:   8%|▊         | 83/986 [00:14<02:33,  5.88it/s]0
#
# Testing DataLoader 0:   9%|▊         | 84/986 [00:14<02:36,  5.77it/s]0
#
# Testing DataLoader 0:   9%|▊         | 85/986 [00:14<02:38,  5.67it/s]0
#
# Testing DataLoader 0:   9%|▊         | 86/986 [00:15<02:38,  5.67it/s]0
#
# Testing DataLoader 0:   9%|▉         | 87/986 [00:15<02:38,  5.69it/s]0
#
# Testing DataLoader 0:   9%|▉         | 88/986 [00:15<02:37,  5.69it/s]0
#
# Testing DataLoader 0:   9%|▉         | 89/986 [00:15<02:39,  5.63it/s]0
#
# Testing DataLoader 0:   9%|▉         | 90/986 [00:16<02:40,  5.57it/s]0
#
# Testing DataLoader 0:   9%|▉         | 91/986 [00:16<02:41,  5.56it/s]0
#
# Testing DataLoader 0:   9%|▉         | 92/986 [00:16<02:40,  5.56it/s]0
#
# Testing DataLoader 0:   9%|▉         | 93/986 [00:16<02:41,  5.54it/s]0
#
# Testing DataLoader 0:  10%|▉         | 94/986 [00:17<02:41,  5.51it/s]0
#
# Testing DataLoader 0:  10%|▉         | 95/986 [00:17<02:41,  5.51it/s]0
#
# Testing DataLoader 0:  10%|▉         | 96/986 [00:17<02:42,  5.49it/s]0
#
# Testing DataLoader 0:  10%|▉         | 97/986 [00:17<02:42,  5.48it/s]0
#
# Testing DataLoader 0:  10%|▉         | 98/986 [00:17<02:41,  5.51it/s]0
#
# Testing DataLoader 0:  10%|█         | 99/986 [00:18<02:42,  5.46it/s]0
#
# Testing DataLoader 0:  10%|█         | 100/986 [00:18<02:41,  5.49it/s]0
#
# Testing DataLoader 0:  10%|█         | 101/986 [00:18<02:40,  5.50it/s]0
#
# Testing DataLoader 0:  10%|█         | 102/986 [00:18<02:39,  5.54it/s]0
#
# Testing DataLoader 0:  10%|█         | 103/986 [00:18<02:39,  5.53it/s]0
#
# Testing DataLoader 0:  11%|█         | 104/986 [00:18<02:39,  5.53it/s]0
#
# Testing DataLoader 0:  11%|█         | 105/986 [00:19<02:40,  5.49it/s]0
#
# Testing DataLoader 0:  11%|█         | 106/986 [00:19<02:42,  5.40it/s]0
#
# Testing DataLoader 0:  11%|█         | 107/986 [00:19<02:41,  5.44it/s]0
#
# Testing DataLoader 0:  11%|█         | 108/986 [00:20<02:43,  5.37it/s]0
#
# Testing DataLoader 0:  11%|█         | 109/986 [00:20<02:43,  5.36it/s]0
#
# Testing DataLoader 0:  11%|█         | 110/986 [00:20<02:43,  5.36it/s]0
#
# Testing DataLoader 0:  11%|█▏        | 111/986 [00:20<02:43,  5.35it/s]0
#
# Testing DataLoader 0:  11%|█▏        | 112/986 [00:20<02:42,  5.38it/s]0
#
# Testing DataLoader 0:  11%|█▏        | 113/986 [00:21<02:43,  5.35it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 114/986 [00:21<02:43,  5.34it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 115/986 [00:21<02:44,  5.28it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 116/986 [00:21<02:43,  5.31it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 117/986 [00:21<02:43,  5.33it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 118/986 [00:22<02:42,  5.35it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 119/986 [00:22<02:41,  5.36it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 120/986 [00:22<02:41,  5.36it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 121/986 [00:22<02:40,  5.38it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 122/986 [00:22<02:40,  5.37it/s]0
#
# Testing DataLoader 0:  12%|█▏        | 123/986 [00:22<02:39,  5.41it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 124/986 [00:23<02:40,  5.38it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 125/986 [00:23<02:41,  5.33it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 126/986 [00:23<02:40,  5.35it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 127/986 [00:23<02:40,  5.35it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 128/986 [00:23<02:39,  5.37it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 129/986 [00:24<02:41,  5.31it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 130/986 [00:24<02:41,  5.30it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 131/986 [00:24<02:40,  5.32it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 132/986 [00:24<02:40,  5.31it/s]0
#
# Testing DataLoader 0:  13%|█▎        | 133/986 [00:24<02:39,  5.34it/s]0
#
# Testing DataLoader 0:  14%|█▎        | 134/986 [00:25<02:40,  5.30it/s]0
#
# Testing DataLoader 0:  14%|█▎        | 135/986 [00:25<02:40,  5.29it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 136/986 [00:25<02:40,  5.31it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 137/986 [00:25<02:39,  5.32it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 138/986 [00:25<02:38,  5.35it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 139/986 [00:26<02:39,  5.31it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 140/986 [00:26<02:39,  5.32it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 141/986 [00:26<02:38,  5.32it/s]0
#
# Testing DataLoader 0:  14%|█▍        | 142/986 [00:26<02:38,  5.33it/s]0
#
# Testing DataLoader 0:  15%|█▍        | 143/986 [00:26<02:38,  5.33it/s]0
#
# Testing DataLoader 0:  15%|█▍        | 144/986 [00:27<02:38,  5.31it/s]0
#
# Testing DataLoader 0:  15%|█▍        | 145/986 [00:27<02:37,  5.33it/s]0
#
# Testing DataLoader 0:  15%|█▍        | 146/986 [00:27<02:37,  5.33it/s]0
#
# Testing DataLoader 0:  15%|█▍        | 147/986 [00:27<02:36,  5.35it/s]0
#
# Testing DataLoader 0:  15%|█▌        | 148/986 [00:27<02:35,  5.37it/s]0
#
# Testing DataLoader 0:  15%|█▌        | 149/986 [00:27<02:35,  5.39it/s]0
#
# Testing DataLoader 0:  15%|█▌        | 150/986 [00:27<02:34,  5.40it/s]0
#
# Testing DataLoader 0:  15%|█▌        | 151/986 [00:27<02:34,  5.39it/s]0
#
# Testing DataLoader 0:  15%|█▌        | 152/986 [00:28<02:35,  5.37it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 153/986 [00:28<02:34,  5.38it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 154/986 [00:28<02:34,  5.37it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 155/986 [00:28<02:34,  5.39it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 156/986 [00:29<02:35,  5.35it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 157/986 [00:29<02:34,  5.37it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 158/986 [00:29<02:33,  5.38it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 159/986 [00:29<02:33,  5.39it/s]0
#
# Testing DataLoader 0:  16%|█▌        | 160/986 [00:29<02:32,  5.40it/s]0
#
# Testing DataLoader 0:  16%|█▋        | 161/986 [00:29<02:32,  5.41it/s]0
#
# Testing DataLoader 0:  16%|█▋        | 162/986 [00:29<02:32,  5.41it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 163/986 [00:30<02:32,  5.40it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 164/986 [00:30<02:31,  5.41it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 165/986 [00:30<02:31,  5.43it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 166/986 [00:30<02:30,  5.44it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 167/986 [00:30<02:30,  5.44it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 168/986 [00:30<02:29,  5.46it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 169/986 [00:30<02:29,  5.47it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 170/986 [00:30<02:28,  5.49it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 171/986 [00:31<02:28,  5.50it/s]0
#
# Testing DataLoader 0:  17%|█▋        | 172/986 [00:31<02:28,  5.49it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 173/986 [00:31<02:27,  5.51it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 174/986 [00:31<02:27,  5.51it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 175/986 [00:32<02:28,  5.45it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 176/986 [00:32<02:28,  5.45it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 177/986 [00:32<02:28,  5.45it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 178/986 [00:32<02:28,  5.45it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 179/986 [00:32<02:28,  5.43it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 180/986 [00:33<02:28,  5.43it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 181/986 [00:33<02:27,  5.44it/s]0
#
# Testing DataLoader 0:  18%|█▊        | 182/986 [00:33<02:27,  5.45it/s]0
#
# Testing DataLoader 0:  19%|█▊        | 183/986 [00:33<02:27,  5.44it/s]0
#
# Testing DataLoader 0:  19%|█▊        | 184/986 [00:33<02:27,  5.45it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 185/986 [00:34<02:27,  5.44it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 186/986 [00:34<02:27,  5.42it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 187/986 [00:34<02:28,  5.39it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 188/986 [00:34<02:27,  5.40it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 189/986 [00:34<02:27,  5.41it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 190/986 [00:35<02:28,  5.37it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 191/986 [00:35<02:27,  5.38it/s]0
#
# Testing DataLoader 0:  19%|█▉        | 192/986 [00:35<02:27,  5.39it/s]0
#
# Testing DataLoader 0:  20%|█▉        | 193/986 [00:35<02:26,  5.41it/s]0
#
# Testing DataLoader 0:  20%|█▉        | 194/986 [00:35<02:26,  5.41it/s]0
#
# Testing DataLoader 0:  20%|█▉        | 195/986 [00:36<02:26,  5.40it/s]0
#
# Testing DataLoader 0:  20%|█▉        | 196/986 [00:36<02:25,  5.42it/s]0
#
# Testing DataLoader 0:  20%|█▉        | 197/986 [00:36<02:25,  5.42it/s]0
#
# Testing DataLoader 0:  20%|██        | 198/986 [00:36<02:24,  5.44it/s]0
#
# Testing DataLoader 0:  20%|██        | 199/986 [00:36<02:25,  5.41it/s]0
#
# Testing DataLoader 0:  20%|██        | 200/986 [00:36<02:25,  5.42it/s]0
#
# Testing DataLoader 0:  20%|██        | 201/986 [00:37<02:24,  5.42it/s]0
#
# Testing DataLoader 0:  20%|██        | 202/986 [00:37<02:24,  5.43it/s]0
#
# Testing DataLoader 0:  21%|██        | 203/986 [00:37<02:23,  5.45it/s]0
#
# Testing DataLoader 0:  21%|██        | 204/986 [00:37<02:23,  5.46it/s]0
#
# Testing DataLoader 0:  21%|██        | 205/986 [00:37<02:22,  5.48it/s]0
#
# Testing DataLoader 0:  21%|██        | 206/986 [00:37<02:23,  5.45it/s]0
#
# Testing DataLoader 0:  21%|██        | 207/986 [00:37<02:22,  5.46it/s]0
#
# Testing DataLoader 0:  21%|██        | 208/986 [00:38<02:22,  5.45it/s]0
#
# Testing DataLoader 0:  21%|██        | 209/986 [00:38<02:22,  5.44it/s]0
#
# Testing DataLoader 0:  21%|██▏       | 210/986 [00:38<02:22,  5.46it/s]0
#
# Testing DataLoader 0:  21%|██▏       | 211/986 [00:38<02:22,  5.46it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 212/986 [00:38<02:21,  5.47it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 213/986 [00:39<02:22,  5.44it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 214/986 [00:39<02:22,  5.41it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 215/986 [00:39<02:22,  5.43it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 216/986 [00:39<02:21,  5.43it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 217/986 [00:39<02:21,  5.44it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 218/986 [00:40<02:21,  5.43it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 219/986 [00:40<02:21,  5.43it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 220/986 [00:40<02:20,  5.44it/s]0
#
# Testing DataLoader 0:  22%|██▏       | 221/986 [00:40<02:20,  5.45it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 222/986 [00:40<02:20,  5.43it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 223/986 [00:41<02:20,  5.43it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 224/986 [00:41<02:20,  5.41it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 225/986 [00:41<02:20,  5.41it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 226/986 [00:41<02:20,  5.43it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 227/986 [00:41<02:19,  5.43it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 228/986 [00:41<02:19,  5.44it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 229/986 [00:42<02:18,  5.45it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 230/986 [00:42<02:18,  5.46it/s]0
#
# Testing DataLoader 0:  23%|██▎       | 231/986 [00:42<02:18,  5.47it/s]0
#
# Testing DataLoader 0:  24%|██▎       | 232/986 [00:42<02:18,  5.46it/s]0
#
# Testing DataLoader 0:  24%|██▎       | 233/986 [00:42<02:17,  5.47it/s]0
#
# Testing DataLoader 0:  24%|██▎       | 234/986 [00:42<02:17,  5.47it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 235/986 [00:42<02:17,  5.47it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 236/986 [00:43<02:17,  5.47it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 237/986 [00:43<02:16,  5.48it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 238/986 [00:43<02:16,  5.48it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 239/986 [00:43<02:16,  5.46it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 240/986 [00:43<02:16,  5.47it/s]0
#
# Testing DataLoader 0:  24%|██▍       | 241/986 [00:44<02:16,  5.47it/s]0
#
# Testing DataLoader 0:  25%|██▍       | 242/986 [00:44<02:16,  5.45it/s]0
#
# Testing DataLoader 0:  25%|██▍       | 243/986 [00:44<02:16,  5.44it/s]0
#
# Testing DataLoader 0:  25%|██▍       | 244/986 [00:45<02:17,  5.41it/s]0
#
# Testing DataLoader 0:  25%|██▍       | 245/986 [00:45<02:16,  5.42it/s]0
#
# Testing DataLoader 0:  25%|██▍       | 246/986 [00:45<02:16,  5.43it/s]0
#
# Testing DataLoader 0:  25%|██▌       | 247/986 [00:45<02:16,  5.43it/s]0
#
# Testing DataLoader 0:  25%|██▌       | 248/986 [00:45<02:16,  5.43it/s]0
#
# Testing DataLoader 0:  25%|██▌       | 249/986 [00:45<02:15,  5.44it/s]0
#
# Testing DataLoader 0:  25%|██▌       | 250/986 [00:45<02:15,  5.45it/s]0
#
# Testing DataLoader 0:  25%|██▌       | 251/986 [00:46<02:14,  5.45it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 252/986 [00:46<02:14,  5.45it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 253/986 [00:46<02:14,  5.46it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 254/986 [00:46<02:14,  5.45it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 255/986 [00:46<02:14,  5.45it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 256/986 [00:46<02:13,  5.45it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 257/986 [00:47<02:14,  5.43it/s]0
#
# Testing DataLoader 0:  26%|██▌       | 258/986 [00:47<02:13,  5.44it/s]0
#
# Testing DataLoader 0:  26%|██▋       | 259/986 [00:47<02:13,  5.45it/s]0
#
# Testing DataLoader 0:  26%|██▋       | 260/986 [00:47<02:13,  5.44it/s]0
#
# Testing DataLoader 0:  26%|██▋       | 261/986 [00:48<02:13,  5.41it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 262/986 [00:48<02:14,  5.39it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 263/986 [00:48<02:14,  5.37it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 264/986 [00:49<02:14,  5.37it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 265/986 [00:49<02:14,  5.38it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 266/986 [00:49<02:14,  5.37it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 267/986 [00:49<02:13,  5.39it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 268/986 [00:49<02:13,  5.40it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 269/986 [00:49<02:13,  5.39it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 270/986 [00:50<02:13,  5.38it/s]0
#
# Testing DataLoader 0:  27%|██▋       | 271/986 [00:50<02:12,  5.38it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 272/986 [00:50<02:12,  5.38it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 273/986 [00:50<02:12,  5.37it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 274/986 [00:51<02:12,  5.36it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 275/986 [00:51<02:12,  5.37it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 276/986 [00:51<02:12,  5.37it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 277/986 [00:51<02:11,  5.38it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 278/986 [00:51<02:11,  5.37it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 279/986 [00:51<02:11,  5.38it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 280/986 [00:51<02:10,  5.40it/s]0
#
# Testing DataLoader 0:  28%|██▊       | 281/986 [00:51<02:10,  5.40it/s]0
#
# Testing DataLoader 0:  29%|██▊       | 282/986 [00:52<02:10,  5.41it/s]0
#
# Testing DataLoader 0:  29%|██▊       | 283/986 [00:52<02:09,  5.41it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 284/986 [00:52<02:09,  5.41it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 285/986 [00:52<02:09,  5.41it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 286/986 [00:52<02:09,  5.42it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 287/986 [00:52<02:08,  5.43it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 288/986 [00:52<02:08,  5.44it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 289/986 [00:53<02:07,  5.45it/s]0
#
# Testing DataLoader 0:  29%|██▉       | 290/986 [00:53<02:07,  5.45it/s]0
#
# Testing DataLoader 0:  30%|██▉       | 291/986 [00:53<02:07,  5.46it/s]0
#
# Testing DataLoader 0:  30%|██▉       | 292/986 [00:53<02:07,  5.43it/s]0
#
# Testing DataLoader 0:  30%|██▉       | 293/986 [00:53<02:07,  5.44it/s]0
#
# Testing DataLoader 0:  30%|██▉       | 294/986 [00:53<02:07,  5.44it/s]0
#
# Testing DataLoader 0:  30%|██▉       | 295/986 [00:54<02:06,  5.45it/s]0
#
# Testing DataLoader 0:  30%|███       | 296/986 [00:54<02:06,  5.46it/s]0
#
# Testing DataLoader 0:  30%|███       | 297/986 [00:54<02:05,  5.48it/s]0
#
# Testing DataLoader 0:  30%|███       | 298/986 [00:54<02:05,  5.49it/s]0
#
# Testing DataLoader 0:  30%|███       | 299/986 [00:54<02:05,  5.49it/s]0
#
# Testing DataLoader 0:  30%|███       | 300/986 [00:54<02:04,  5.50it/s]0
#
# Testing DataLoader 0:  31%|███       | 301/986 [00:54<02:04,  5.50it/s]0
#
# Testing DataLoader 0:  31%|███       | 302/986 [00:54<02:04,  5.51it/s]0
#
# Testing DataLoader 0:  31%|███       | 303/986 [00:54<02:03,  5.52it/s]0
#
# Testing DataLoader 0:  31%|███       | 304/986 [00:55<02:03,  5.52it/s]0
#
# Testing DataLoader 0:  31%|███       | 305/986 [00:55<02:03,  5.52it/s]0
#
# Testing DataLoader 0:  31%|███       | 306/986 [00:55<02:03,  5.52it/s]0
#
# Testing DataLoader 0:  31%|███       | 307/986 [00:55<02:02,  5.53it/s]0
#
# Testing DataLoader 0:  31%|███       | 308/986 [00:55<02:02,  5.54it/s]0
#
# Testing DataLoader 0:  31%|███▏      | 309/986 [00:55<02:02,  5.54it/s]0
#
# Testing DataLoader 0:  31%|███▏      | 310/986 [00:55<02:02,  5.54it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 311/986 [00:56<02:02,  5.53it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 312/986 [00:56<02:01,  5.53it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 313/986 [00:56<02:01,  5.54it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 314/986 [00:56<02:01,  5.53it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 315/986 [00:56<02:01,  5.53it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 316/986 [00:57<02:01,  5.53it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 317/986 [00:57<02:01,  5.52it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 318/986 [00:57<02:01,  5.52it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 319/986 [00:57<02:00,  5.52it/s]0
#
# Testing DataLoader 0:  32%|███▏      | 320/986 [00:58<02:01,  5.50it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 321/986 [00:58<02:00,  5.50it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 322/986 [00:58<02:00,  5.50it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 323/986 [00:58<02:00,  5.51it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 324/986 [00:58<01:59,  5.52it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 325/986 [00:58<01:59,  5.52it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 326/986 [00:59<01:59,  5.52it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 327/986 [00:59<01:59,  5.53it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 328/986 [00:59<01:58,  5.53it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 329/986 [00:59<01:58,  5.53it/s]0
#
# Testing DataLoader 0:  33%|███▎      | 330/986 [00:59<01:58,  5.52it/s]0
#
# Testing DataLoader 0:  34%|███▎      | 331/986 [00:59<01:58,  5.52it/s]0
#
# Testing DataLoader 0:  34%|███▎      | 332/986 [00:59<01:58,  5.53it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 333/986 [01:00<01:57,  5.54it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 334/986 [01:00<01:57,  5.54it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 335/986 [01:00<01:57,  5.54it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 336/986 [01:00<01:57,  5.56it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 337/986 [01:00<01:57,  5.54it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 338/986 [01:00<01:56,  5.54it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 339/986 [01:01<01:56,  5.56it/s]0
#
# Testing DataLoader 0:  34%|███▍      | 340/986 [01:01<01:56,  5.56it/s]0
#
# Testing DataLoader 0:  35%|███▍      | 341/986 [01:01<01:56,  5.56it/s]0
#
# Testing DataLoader 0:  35%|███▍      | 342/986 [01:01<01:55,  5.57it/s]0
#
# Testing DataLoader 0:  35%|███▍      | 343/986 [01:01<01:55,  5.58it/s]0
#
# Testing DataLoader 0:  35%|███▍      | 344/986 [01:01<01:54,  5.59it/s]0
#
# Testing DataLoader 0:  35%|███▍      | 345/986 [01:01<01:54,  5.59it/s]0
#
# Testing DataLoader 0:  35%|███▌      | 346/986 [01:01<01:54,  5.59it/s]0
#
# Testing DataLoader 0:  35%|███▌      | 347/986 [01:02<01:54,  5.59it/s]0
#
# Testing DataLoader 0:  35%|███▌      | 348/986 [01:02<01:54,  5.58it/s]0
#
# Testing DataLoader 0:  35%|███▌      | 349/986 [01:02<01:54,  5.59it/s]0
#
# Testing DataLoader 0:  35%|███▌      | 350/986 [01:02<01:53,  5.58it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 351/986 [01:02<01:53,  5.57it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 352/986 [01:03<01:53,  5.58it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 353/986 [01:03<01:53,  5.58it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 354/986 [01:03<01:53,  5.58it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 355/986 [01:03<01:52,  5.59it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 356/986 [01:03<01:52,  5.58it/s]0
#
# Testing DataLoader 0:  36%|███▌      | 357/986 [01:03<01:52,  5.59it/s]0
#
# Testing DataLoader 0:  36%|███▋      | 358/986 [01:04<01:52,  5.59it/s]0
#
# Testing DataLoader 0:  36%|███▋      | 359/986 [01:04<01:52,  5.56it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 360/986 [01:04<01:52,  5.55it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 361/986 [01:04<01:52,  5.56it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 362/986 [01:04<01:51,  5.58it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 363/986 [01:05<01:51,  5.58it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 364/986 [01:05<01:51,  5.58it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 365/986 [01:05<01:51,  5.56it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 366/986 [01:05<01:51,  5.56it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 367/986 [01:06<01:51,  5.55it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 368/986 [01:06<01:51,  5.54it/s]0
#
# Testing DataLoader 0:  37%|███▋      | 369/986 [01:06<01:51,  5.53it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 370/986 [01:06<01:51,  5.54it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 371/986 [01:06<01:50,  5.55it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 372/986 [01:06<01:50,  5.55it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 373/986 [01:07<01:50,  5.55it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 374/986 [01:07<01:50,  5.56it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 375/986 [01:07<01:50,  5.55it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 376/986 [01:07<01:49,  5.56it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 377/986 [01:07<01:49,  5.57it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 378/986 [01:07<01:48,  5.58it/s]0
#
# Testing DataLoader 0:  38%|███▊      | 379/986 [01:07<01:48,  5.58it/s]0
#
# Testing DataLoader 0:  39%|███▊      | 380/986 [01:08<01:48,  5.59it/s]0
#
# Testing DataLoader 0:  39%|███▊      | 381/986 [01:08<01:48,  5.59it/s]0
#
# Testing DataLoader 0:  39%|███▊      | 382/986 [01:08<01:47,  5.59it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 383/986 [01:08<01:47,  5.60it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 384/986 [01:08<01:47,  5.60it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 385/986 [01:08<01:47,  5.61it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 386/986 [01:08<01:46,  5.62it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 387/986 [01:09<01:46,  5.60it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 388/986 [01:09<01:46,  5.61it/s]0
#
# Testing DataLoader 0:  39%|███▉      | 389/986 [01:09<01:46,  5.62it/s]0
#
# Testing DataLoader 0:  40%|███▉      | 390/986 [01:09<01:45,  5.62it/s]0
#
# Testing DataLoader 0:  40%|███▉      | 391/986 [01:09<01:45,  5.63it/s]0
#
# Testing DataLoader 0:  40%|███▉      | 392/986 [01:09<01:45,  5.62it/s]0
#
# Testing DataLoader 0:  40%|███▉      | 393/986 [01:09<01:45,  5.63it/s]0
#
# Testing DataLoader 0:  40%|███▉      | 394/986 [01:09<01:45,  5.63it/s]0
#
# Testing DataLoader 0:  40%|████      | 395/986 [01:10<01:45,  5.63it/s]0
#
# Testing DataLoader 0:  40%|████      | 396/986 [01:10<01:44,  5.62it/s]0
#
# Testing DataLoader 0:  40%|████      | 397/986 [01:10<01:44,  5.63it/s]0
#
# Testing DataLoader 0:  40%|████      | 398/986 [01:10<01:44,  5.64it/s]0
#
# Testing DataLoader 0:  40%|████      | 399/986 [01:10<01:44,  5.64it/s]0
#
# Testing DataLoader 0:  41%|████      | 400/986 [01:10<01:43,  5.64it/s]0
#
# Testing DataLoader 0:  41%|████      | 401/986 [01:11<01:43,  5.63it/s]0
#
# Testing DataLoader 0:  41%|████      | 402/986 [01:11<01:44,  5.61it/s]0
#
# Testing DataLoader 0:  41%|████      | 403/986 [01:11<01:44,  5.60it/s]0
#
# Testing DataLoader 0:  41%|████      | 404/986 [01:12<01:43,  5.61it/s]0
#
# Testing DataLoader 0:  41%|████      | 405/986 [01:12<01:43,  5.61it/s]0
#
# Testing DataLoader 0:  41%|████      | 406/986 [01:12<01:43,  5.62it/s]0
#
# Testing DataLoader 0:  41%|████▏     | 407/986 [01:12<01:42,  5.63it/s]0
#
# Testing DataLoader 0:  41%|████▏     | 408/986 [01:12<01:42,  5.61it/s]0
#
# Testing DataLoader 0:  41%|████▏     | 409/986 [01:12<01:42,  5.61it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 410/986 [01:12<01:42,  5.62it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 411/986 [01:13<01:42,  5.62it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 412/986 [01:13<01:42,  5.62it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 413/986 [01:13<01:41,  5.63it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 414/986 [01:13<01:41,  5.63it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 415/986 [01:13<01:41,  5.64it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 416/986 [01:13<01:41,  5.63it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 417/986 [01:13<01:40,  5.64it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 418/986 [01:14<01:40,  5.63it/s]0
#
# Testing DataLoader 0:  42%|████▏     | 419/986 [01:14<01:40,  5.64it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 420/986 [01:14<01:40,  5.62it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 421/986 [01:14<01:40,  5.62it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 422/986 [01:15<01:40,  5.61it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 423/986 [01:15<01:40,  5.62it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 424/986 [01:15<01:40,  5.60it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 425/986 [01:15<01:40,  5.61it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 426/986 [01:15<01:39,  5.61it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 427/986 [01:16<01:39,  5.61it/s]0
#
# Testing DataLoader 0:  43%|████▎     | 428/986 [01:16<01:39,  5.62it/s]0
#
# Testing DataLoader 0:  44%|████▎     | 429/986 [01:16<01:39,  5.61it/s]0
#
# Testing DataLoader 0:  44%|████▎     | 430/986 [01:16<01:38,  5.62it/s]0
#
# Testing DataLoader 0:  44%|████▎     | 431/986 [01:16<01:38,  5.62it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 432/986 [01:16<01:38,  5.63it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 433/986 [01:16<01:38,  5.63it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 434/986 [01:17<01:38,  5.62it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 435/986 [01:17<01:38,  5.61it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 436/986 [01:17<01:37,  5.62it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 437/986 [01:17<01:37,  5.61it/s]0
#
# Testing DataLoader 0:  44%|████▍     | 438/986 [01:18<01:37,  5.61it/s]0
#
# Testing DataLoader 0:  45%|████▍     | 439/986 [01:18<01:37,  5.60it/s]0
#
# Testing DataLoader 0:  45%|████▍     | 440/986 [01:18<01:37,  5.61it/s]0
#
# Testing DataLoader 0:  45%|████▍     | 441/986 [01:18<01:37,  5.61it/s]0
#
# Testing DataLoader 0:  45%|████▍     | 442/986 [01:18<01:36,  5.62it/s]0
#
# Testing DataLoader 0:  45%|████▍     | 443/986 [01:19<01:36,  5.60it/s]0
#
# Testing DataLoader 0:  45%|████▌     | 444/986 [01:19<01:36,  5.60it/s]0
#
# Testing DataLoader 0:  45%|████▌     | 445/986 [01:19<01:36,  5.60it/s]0
#
# Testing DataLoader 0:  45%|████▌     | 446/986 [01:19<01:36,  5.60it/s]0
#
# Testing DataLoader 0:  45%|████▌     | 447/986 [01:19<01:36,  5.61it/s]0
#
# Testing DataLoader 0:  45%|████▌     | 448/986 [01:19<01:35,  5.61it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 449/986 [01:20<01:36,  5.59it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 450/986 [01:20<01:36,  5.58it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 451/986 [01:20<01:35,  5.58it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 452/986 [01:21<01:35,  5.58it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 453/986 [01:21<01:35,  5.56it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 454/986 [01:21<01:35,  5.56it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 455/986 [01:21<01:35,  5.57it/s]0
#
# Testing DataLoader 0:  46%|████▌     | 456/986 [01:21<01:35,  5.56it/s]0
#
# Testing DataLoader 0:  46%|████▋     | 457/986 [01:22<01:35,  5.55it/s]0
#
# Testing DataLoader 0:  46%|████▋     | 458/986 [01:22<01:35,  5.55it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 459/986 [01:22<01:35,  5.54it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 460/986 [01:22<01:34,  5.55it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 461/986 [01:23<01:34,  5.54it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 462/986 [01:23<01:34,  5.53it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 463/986 [01:23<01:34,  5.54it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 464/986 [01:23<01:34,  5.54it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 465/986 [01:24<01:34,  5.53it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 466/986 [01:24<01:33,  5.54it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 467/986 [01:24<01:33,  5.55it/s]0
#
# Testing DataLoader 0:  47%|████▋     | 468/986 [01:24<01:33,  5.55it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 469/986 [01:24<01:32,  5.56it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 470/986 [01:24<01:32,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 471/986 [01:24<01:32,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 472/986 [01:24<01:32,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 473/986 [01:24<01:32,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 474/986 [01:25<01:31,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 475/986 [01:25<01:31,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 476/986 [01:25<01:31,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 477/986 [01:25<01:31,  5.57it/s]0
#
# Testing DataLoader 0:  48%|████▊     | 478/986 [01:25<01:31,  5.57it/s]0
#
# Testing DataLoader 0:  49%|████▊     | 479/986 [01:25<01:31,  5.57it/s]0
#
# Testing DataLoader 0:  49%|████▊     | 480/986 [01:26<01:30,  5.57it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 481/986 [01:26<01:31,  5.55it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 482/986 [01:26<01:30,  5.55it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 483/986 [01:26<01:30,  5.55it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 484/986 [01:27<01:30,  5.55it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 485/986 [01:27<01:30,  5.56it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 486/986 [01:27<01:29,  5.56it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 487/986 [01:27<01:29,  5.57it/s]0
#
# Testing DataLoader 0:  49%|████▉     | 488/986 [01:27<01:29,  5.56it/s]0
#
# Testing DataLoader 0:  50%|████▉     | 489/986 [01:27<01:29,  5.56it/s]0
#
# Testing DataLoader 0:  50%|████▉     | 490/986 [01:28<01:29,  5.56it/s]0
#
# Testing DataLoader 0:  50%|████▉     | 491/986 [01:28<01:28,  5.57it/s]0
#
# Testing DataLoader 0:  50%|████▉     | 492/986 [01:28<01:28,  5.58it/s]0
#
# Testing DataLoader 0:  50%|█████     | 493/986 [01:28<01:28,  5.57it/s]0
#
# Testing DataLoader 0:  50%|█████     | 494/986 [01:28<01:28,  5.58it/s]0
#
# Testing DataLoader 0:  50%|█████     | 495/986 [01:28<01:27,  5.58it/s]0
#
# Testing DataLoader 0:  50%|█████     | 496/986 [01:28<01:27,  5.58it/s]0
#
# Testing DataLoader 0:  50%|█████     | 497/986 [01:28<01:27,  5.59it/s]0
#
# Testing DataLoader 0:  51%|█████     | 498/986 [01:28<01:27,  5.60it/s]0
#
# Testing DataLoader 0:  51%|█████     | 499/986 [01:29<01:26,  5.60it/s]0
#
# Testing DataLoader 0:  51%|█████     | 500/986 [01:29<01:26,  5.61it/s]0
#
# Testing DataLoader 0:  51%|█████     | 501/986 [01:29<01:26,  5.61it/s]0
#
# Testing DataLoader 0:  51%|█████     | 502/986 [01:29<01:26,  5.60it/s]0
#
# Testing DataLoader 0:  51%|█████     | 503/986 [01:29<01:26,  5.60it/s]0
#
# Testing DataLoader 0:  51%|█████     | 504/986 [01:29<01:25,  5.61it/s]0
#
# Testing DataLoader 0:  51%|█████     | 505/986 [01:30<01:25,  5.61it/s]0
#
# Testing DataLoader 0:  51%|█████▏    | 506/986 [01:30<01:25,  5.61it/s]0
#
# Testing DataLoader 0:  51%|█████▏    | 507/986 [01:30<01:25,  5.61it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 508/986 [01:30<01:25,  5.61it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 509/986 [01:30<01:25,  5.60it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 510/986 [01:31<01:25,  5.59it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 511/986 [01:31<01:24,  5.60it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 512/986 [01:31<01:24,  5.60it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 513/986 [01:31<01:24,  5.59it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 514/986 [01:31<01:24,  5.60it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 515/986 [01:31<01:24,  5.61it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 516/986 [01:32<01:23,  5.61it/s]0
#
# Testing DataLoader 0:  52%|█████▏    | 517/986 [01:32<01:23,  5.61it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 518/986 [01:32<01:23,  5.61it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 519/986 [01:32<01:23,  5.61it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 520/986 [01:32<01:23,  5.60it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 521/986 [01:33<01:23,  5.60it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 522/986 [01:33<01:22,  5.60it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 523/986 [01:33<01:22,  5.60it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 524/986 [01:33<01:22,  5.61it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 525/986 [01:33<01:22,  5.61it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 526/986 [01:33<01:21,  5.62it/s]0
#
# Testing DataLoader 0:  53%|█████▎    | 527/986 [01:33<01:21,  5.61it/s]0
#
# Testing DataLoader 0:  54%|█████▎    | 528/986 [01:34<01:21,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▎    | 529/986 [01:34<01:21,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 530/986 [01:34<01:21,  5.61it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 531/986 [01:34<01:21,  5.61it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 532/986 [01:34<01:20,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 533/986 [01:34<01:20,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 534/986 [01:34<01:20,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 535/986 [01:35<01:20,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 536/986 [01:35<01:20,  5.62it/s]0
#
# Testing DataLoader 0:  54%|█████▍    | 537/986 [01:35<01:19,  5.63it/s]0
#
# Testing DataLoader 0:  55%|█████▍    | 538/986 [01:35<01:19,  5.63it/s]0
#
# Testing DataLoader 0:  55%|█████▍    | 539/986 [01:35<01:19,  5.63it/s]0
#
# Testing DataLoader 0:  55%|█████▍    | 540/986 [01:35<01:19,  5.64it/s]0
#
# Testing DataLoader 0:  55%|█████▍    | 541/986 [01:35<01:18,  5.64it/s]0
#
# Testing DataLoader 0:  55%|█████▍    | 542/986 [01:36<01:18,  5.64it/s]0
#
# Testing DataLoader 0:  55%|█████▌    | 543/986 [01:36<01:18,  5.64it/s]0
#
# Testing DataLoader 0:  55%|█████▌    | 544/986 [01:36<01:18,  5.64it/s]0
#
# Testing DataLoader 0:  55%|█████▌    | 545/986 [01:36<01:18,  5.65it/s]0
#
# Testing DataLoader 0:  55%|█████▌    | 546/986 [01:36<01:18,  5.64it/s]0
#
# Testing DataLoader 0:  55%|█████▌    | 547/986 [01:36<01:17,  5.65it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 548/986 [01:37<01:17,  5.64it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 549/986 [01:37<01:17,  5.63it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 550/986 [01:37<01:17,  5.63it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 551/986 [01:37<01:17,  5.64it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 552/986 [01:37<01:16,  5.64it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 553/986 [01:37<01:16,  5.65it/s]0
#
# Testing DataLoader 0:  56%|█████▌    | 554/986 [01:38<01:16,  5.64it/s]0
#
# Testing DataLoader 0:  56%|█████▋    | 555/986 [01:38<01:16,  5.64it/s]0
#
# Testing DataLoader 0:  56%|█████▋    | 556/986 [01:38<01:16,  5.64it/s]0
#
# Testing DataLoader 0:  56%|█████▋    | 557/986 [01:38<01:16,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 558/986 [01:38<01:15,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 559/986 [01:39<01:15,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 560/986 [01:39<01:15,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 561/986 [01:39<01:15,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 562/986 [01:39<01:15,  5.65it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 563/986 [01:39<01:15,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 564/986 [01:39<01:14,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 565/986 [01:40<01:14,  5.64it/s]0
#
# Testing DataLoader 0:  57%|█████▋    | 566/986 [01:40<01:14,  5.64it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 567/986 [01:40<01:14,  5.64it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 568/986 [01:40<01:14,  5.64it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 569/986 [01:40<01:13,  5.64it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 570/986 [01:40<01:13,  5.65it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 571/986 [01:41<01:13,  5.65it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 572/986 [01:41<01:13,  5.65it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 573/986 [01:41<01:13,  5.65it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 574/986 [01:41<01:12,  5.66it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 575/986 [01:41<01:12,  5.65it/s]0
#
# Testing DataLoader 0:  58%|█████▊    | 576/986 [01:41<01:12,  5.65it/s]0
#
# Testing DataLoader 0:  59%|█████▊    | 577/986 [01:42<01:12,  5.65it/s]0
#
# Testing DataLoader 0:  59%|█████▊    | 578/986 [01:42<01:12,  5.66it/s]0
#
# Testing DataLoader 0:  59%|█████▊    | 579/986 [01:42<01:11,  5.66it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 580/986 [01:42<01:11,  5.66it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 581/986 [01:42<01:11,  5.66it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 582/986 [01:42<01:11,  5.66it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 583/986 [01:42<01:11,  5.66it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 584/986 [01:43<01:11,  5.65it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 585/986 [01:43<01:11,  5.65it/s]0
#
# Testing DataLoader 0:  59%|█████▉    | 586/986 [01:43<01:10,  5.65it/s]0
#
# Testing DataLoader 0:  60%|█████▉    | 587/986 [01:43<01:10,  5.66it/s]0
#
# Testing DataLoader 0:  60%|█████▉    | 588/986 [01:43<01:10,  5.66it/s]0
#
# Testing DataLoader 0:  60%|█████▉    | 589/986 [01:44<01:10,  5.66it/s]0
#
# Testing DataLoader 0:  60%|█████▉    | 590/986 [01:44<01:10,  5.66it/s]0
#
# Testing DataLoader 0:  60%|█████▉    | 591/986 [01:44<01:09,  5.66it/s]0
#
# Testing DataLoader 0:  60%|██████    | 592/986 [01:44<01:09,  5.66it/s]0
#
# Testing DataLoader 0:  60%|██████    | 593/986 [01:44<01:09,  5.66it/s]0
#
# Testing DataLoader 0:  60%|██████    | 594/986 [01:44<01:09,  5.66it/s]0
#
# Testing DataLoader 0:  60%|██████    | 595/986 [01:45<01:09,  5.67it/s]0
#
# Testing DataLoader 0:  60%|██████    | 596/986 [01:45<01:08,  5.66it/s]0
#
# Testing DataLoader 0:  61%|██████    | 597/986 [01:45<01:08,  5.67it/s]0
#
# Testing DataLoader 0:  61%|██████    | 598/986 [01:45<01:08,  5.67it/s]0
#
# Testing DataLoader 0:  61%|██████    | 599/986 [01:45<01:08,  5.67it/s]0
#
# Testing DataLoader 0:  61%|██████    | 600/986 [01:45<01:07,  5.68it/s]0
#
# Testing DataLoader 0:  61%|██████    | 601/986 [01:45<01:07,  5.68it/s]0
#
# Testing DataLoader 0:  61%|██████    | 602/986 [01:46<01:07,  5.68it/s]0
#
# Testing DataLoader 0:  61%|██████    | 603/986 [01:46<01:07,  5.68it/s]0
#
# Testing DataLoader 0:  61%|██████▏   | 604/986 [01:46<01:07,  5.68it/s]0
#
# Testing DataLoader 0:  61%|██████▏   | 605/986 [01:46<01:06,  5.69it/s]0
#
# Testing DataLoader 0:  61%|██████▏   | 606/986 [01:46<01:06,  5.69it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 607/986 [01:46<01:06,  5.69it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 608/986 [01:46<01:06,  5.70it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 609/986 [01:46<01:06,  5.70it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 610/986 [01:47<01:05,  5.70it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 611/986 [01:47<01:05,  5.70it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 612/986 [01:47<01:05,  5.70it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 613/986 [01:47<01:05,  5.70it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 614/986 [01:47<01:05,  5.71it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 615/986 [01:47<01:04,  5.71it/s]0
#
# Testing DataLoader 0:  62%|██████▏   | 616/986 [01:47<01:04,  5.71it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 617/986 [01:48<01:04,  5.71it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 618/986 [01:48<01:04,  5.69it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 619/986 [01:48<01:04,  5.70it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 620/986 [01:48<01:04,  5.70it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 621/986 [01:48<01:04,  5.70it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 622/986 [01:49<01:03,  5.70it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 623/986 [01:49<01:03,  5.70it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 624/986 [01:49<01:03,  5.68it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 625/986 [01:49<01:03,  5.69it/s]0
#
# Testing DataLoader 0:  63%|██████▎   | 626/986 [01:49<01:03,  5.70it/s]0
#
# Testing DataLoader 0:  64%|██████▎   | 627/986 [01:49<01:02,  5.70it/s]0
#
# Testing DataLoader 0:  64%|██████▎   | 628/986 [01:50<01:02,  5.71it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 629/986 [01:50<01:02,  5.71it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 630/986 [01:50<01:02,  5.72it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 631/986 [01:50<01:02,  5.70it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 632/986 [01:50<01:02,  5.71it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 633/986 [01:50<01:01,  5.70it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 634/986 [01:51<01:01,  5.70it/s]0
#
# Testing DataLoader 0:  64%|██████▍   | 635/986 [01:51<01:01,  5.70it/s]0
#
# Testing DataLoader 0:  65%|██████▍   | 636/986 [01:51<01:01,  5.69it/s]0
#
# Testing DataLoader 0:  65%|██████▍   | 637/986 [01:51<01:01,  5.69it/s]0
#
# Testing DataLoader 0:  65%|██████▍   | 638/986 [01:52<01:01,  5.68it/s]0
#
# Testing DataLoader 0:  65%|██████▍   | 639/986 [01:52<01:01,  5.68it/s]0
#
# Testing DataLoader 0:  65%|██████▍   | 640/986 [01:52<01:00,  5.67it/s]0
#
# Testing DataLoader 0:  65%|██████▌   | 641/986 [01:52<01:00,  5.68it/s]0
#
# Testing DataLoader 0:  65%|██████▌   | 642/986 [01:53<01:00,  5.66it/s]0
#
# ...
#
# Testing DataLoader 0:  79%|███████▉  | 781/986 [02:18<00:36,  5.66it/s]0
#
# Testing DataLoader 0:  79%|███████▉  | 782/986 [02:18<00:36,  5.65it/s]0
#
# Testing DataLoader 0:  79%|███████▉  | 783/986 [02:18<00:35,  5.65it/s]0
#
# Testing DataLoader 0:  80%|███████▉  | 784/986 [02:18<00:35,  5.65it/s]0
#
# Testing DataLoader 0:  80%|███████▉  | 785/986 [02:18<00:35,  5.65it/s]0
#
# Testing DataLoader 0:  80%|███████▉  | 786/986 [02:18<00:35,  5.65it/s]0
#
# Testing DataLoader 0:  80%|███████▉  | 787/986 [02:19<00:35,  5.65it/s]0
#
# Testing DataLoader 0:  80%|███████▉  | 788/986 [02:19<00:35,  5.64it/s]0
#
# Testing DataLoader 0:  80%|████████  | 789/986 [02:19<00:34,  5.64it/s]0
#
# Testing DataLoader 0:  80%|████████  | 790/986 [02:20<00:34,  5.64it/s]0
#
# Testing DataLoader 0:  80%|████████  | 791/986 [02:20<00:34,  5.64it/s]0
#
# Testing DataLoader 0:  80%|████████  | 792/986 [02:20<00:34,  5.64it/s]0
#
# Testing DataLoader 0:  80%|████████  | 793/986 [02:20<00:34,  5.65it/s]0
#
# Testing DataLoader 0:  81%|████████  | 794/986 [02:20<00:33,  5.65it/s]0
#
# Testing DataLoader 0:  81%|████████  | 795/986 [02:20<00:33,  5.65it/s]0
#
# Testing DataLoader 0:  81%|████████  | 796/986 [02:20<00:33,  5.65it/s]0
#
# Testing DataLoader 0:  81%|████████  | 797/986 [02:21<00:33,  5.65it/s]0
#
# Testing DataLoader 0:  81%|████████  | 798/986 [02:21<00:33,  5.65it/s]0
#
# Testing DataLoader 0:  81%|████████  | 799/986 [02:21<00:33,  5.66it/s]0
#
# Testing DataLoader 0:  81%|████████  | 800/986 [02:21<00:32,  5.66it/s]0
#
# Testing DataLoader 0:  81%|████████  | 801/986 [02:21<00:32,  5.66it/s]0
#
# Testing DataLoader 0:  81%|████████▏ | 802/986 [02:21<00:32,  5.67it/s]0
#
# Testing DataLoader 0:  81%|████████▏ | 803/986 [02:21<00:32,  5.66it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 804/986 [02:22<00:32,  5.66it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 805/986 [02:22<00:32,  5.65it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 806/986 [02:22<00:31,  5.65it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 807/986 [02:22<00:31,  5.65it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 808/986 [02:22<00:31,  5.65it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 809/986 [02:22<00:31,  5.66it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 810/986 [02:23<00:31,  5.66it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 811/986 [02:23<00:30,  5.66it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 812/986 [02:23<00:30,  5.66it/s]0
#
# Testing DataLoader 0:  82%|████████▏ | 813/986 [02:23<00:30,  5.66it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 814/986 [02:23<00:30,  5.67it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 815/986 [02:23<00:30,  5.66it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 816/986 [02:24<00:30,  5.67it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 817/986 [02:24<00:29,  5.67it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 818/986 [02:24<00:29,  5.68it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 819/986 [02:24<00:29,  5.67it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 820/986 [02:24<00:29,  5.67it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 821/986 [02:24<00:29,  5.68it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 822/986 [02:24<00:28,  5.67it/s]0
#
# Testing DataLoader 0:  83%|████████▎ | 823/986 [02:25<00:28,  5.67it/s]0
#
# Testing DataLoader 0:  84%|████████▎ | 824/986 [02:25<00:28,  5.67it/s]0
#
# Testing DataLoader 0:  84%|████████▎ | 825/986 [02:25<00:28,  5.67it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 826/986 [02:25<00:28,  5.66it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 827/986 [02:25<00:28,  5.67it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 828/986 [02:26<00:27,  5.67it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 829/986 [02:26<00:27,  5.66it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 830/986 [02:26<00:27,  5.65it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 831/986 [02:27<00:27,  5.65it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 832/986 [02:27<00:27,  5.65it/s]0
#
# Testing DataLoader 0:  84%|████████▍ | 833/986 [02:27<00:27,  5.65it/s]0
#
# Testing DataLoader 0:  85%|████████▍ | 834/986 [02:27<00:26,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▍ | 835/986 [02:27<00:26,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▍ | 836/986 [02:28<00:26,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▍ | 837/986 [02:28<00:26,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▍ | 838/986 [02:28<00:26,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▌ | 839/986 [02:28<00:26,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▌ | 840/986 [02:28<00:25,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▌ | 841/986 [02:29<00:25,  5.64it/s]0
#
# Testing DataLoader 0:  85%|████████▌ | 842/986 [02:29<00:25,  5.65it/s]0
#
# Testing DataLoader 0:  85%|████████▌ | 843/986 [02:29<00:25,  5.65it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 844/986 [02:29<00:25,  5.65it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 845/986 [02:29<00:24,  5.65it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 846/986 [02:29<00:24,  5.65it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 847/986 [02:30<00:24,  5.64it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 848/986 [02:30<00:24,  5.64it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 849/986 [02:30<00:24,  5.63it/s]0
#
# Testing DataLoader 0:  86%|████████▌ | 850/986 [02:30<00:24,  5.63it/s]0
#
# Testing DataLoader 0:  86%|████████▋ | 851/986 [02:31<00:23,  5.63it/s]0
#
# Testing DataLoader 0:  86%|████████▋ | 852/986 [02:31<00:23,  5.63it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 853/986 [02:31<00:23,  5.63it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 854/986 [02:31<00:23,  5.63it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 855/986 [02:32<00:23,  5.62it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 856/986 [02:32<00:23,  5.62it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 857/986 [02:32<00:22,  5.61it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 858/986 [02:32<00:22,  5.61it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 859/986 [02:33<00:22,  5.61it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 860/986 [02:33<00:22,  5.61it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 861/986 [02:33<00:22,  5.61it/s]0
#
# Testing DataLoader 0:  87%|████████▋ | 862/986 [02:33<00:22,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 863/986 [02:33<00:21,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 864/986 [02:34<00:21,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 865/986 [02:34<00:21,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 866/986 [02:34<00:21,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 867/986 [02:34<00:21,  5.62it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 868/986 [02:34<00:21,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 869/986 [02:34<00:20,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 870/986 [02:34<00:20,  5.61it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 871/986 [02:35<00:20,  5.62it/s]0
#
# Testing DataLoader 0:  88%|████████▊ | 872/986 [02:35<00:20,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▊ | 873/986 [02:35<00:20,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▊ | 874/986 [02:35<00:19,  5.63it/s]0
#
# Testing DataLoader 0:  89%|████████▊ | 875/986 [02:35<00:19,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 876/986 [02:35<00:19,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 877/986 [02:36<00:19,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 878/986 [02:36<00:19,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 879/986 [02:36<00:19,  5.62it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 880/986 [02:36<00:18,  5.61it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 881/986 [02:37<00:18,  5.61it/s]0
#
# Testing DataLoader 0:  89%|████████▉ | 882/986 [02:37<00:18,  5.61it/s]0
#
# Testing DataLoader 0:  90%|████████▉ | 883/986 [02:37<00:18,  5.61it/s]0
#
# Testing DataLoader 0:  90%|████████▉ | 884/986 [02:37<00:18,  5.62it/s]0
#
# Testing DataLoader 0:  90%|████████▉ | 885/986 [02:37<00:17,  5.62it/s]0
#
# Testing DataLoader 0:  90%|████████▉ | 886/986 [02:37<00:17,  5.62it/s]0
#
# Testing DataLoader 0:  90%|████████▉ | 887/986 [02:37<00:17,  5.62it/s]0
#
# Testing DataLoader 0:  90%|█████████ | 888/986 [02:37<00:17,  5.62it/s]0
#
# Testing DataLoader 0:  90%|█████████ | 889/986 [02:37<00:17,  5.63it/s]0
#
# Testing DataLoader 0:  90%|█████████ | 890/986 [02:38<00:17,  5.63it/s]0
#
# Testing DataLoader 0:  90%|█████████ | 891/986 [02:38<00:16,  5.63it/s]0
#
# Testing DataLoader 0:  90%|█████████ | 892/986 [02:38<00:16,  5.63it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 893/986 [02:38<00:16,  5.63it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 894/986 [02:38<00:16,  5.63it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 895/986 [02:38<00:16,  5.63it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 896/986 [02:39<00:15,  5.63it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 897/986 [02:39<00:15,  5.64it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 898/986 [02:39<00:15,  5.63it/s]0
#
# Testing DataLoader 0:  91%|█████████ | 899/986 [02:39<00:15,  5.64it/s]0
#
# Testing DataLoader 0:  91%|█████████▏| 900/986 [02:39<00:15,  5.64it/s]0
#
# Testing DataLoader 0:  91%|█████████▏| 901/986 [02:39<00:15,  5.64it/s]0
#
# Testing DataLoader 0:  91%|█████████▏| 902/986 [02:39<00:14,  5.64it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 903/986 [02:40<00:14,  5.64it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 904/986 [02:40<00:14,  5.64it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 905/986 [02:40<00:14,  5.65it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 906/986 [02:40<00:14,  5.65it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 907/986 [02:40<00:13,  5.65it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 908/986 [02:40<00:13,  5.64it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 909/986 [02:40<00:13,  5.65it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 910/986 [02:41<00:13,  5.64it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 911/986 [02:41<00:13,  5.65it/s]0
#
# Testing DataLoader 0:  92%|█████████▏| 912/986 [02:41<00:13,  5.65it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 913/986 [02:41<00:12,  5.66it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 914/986 [02:41<00:12,  5.65it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 915/986 [02:42<00:12,  5.65it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 916/986 [02:42<00:12,  5.64it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 917/986 [02:42<00:12,  5.64it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 918/986 [02:42<00:12,  5.64it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 919/986 [02:42<00:11,  5.64it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 920/986 [02:42<00:11,  5.64it/s]0
#
# Testing DataLoader 0:  93%|█████████▎| 921/986 [02:43<00:11,  5.64it/s]0
#
# Testing DataLoader 0:  94%|█████████▎| 922/986 [02:43<00:11,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▎| 923/986 [02:43<00:11,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▎| 924/986 [02:43<00:10,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 925/986 [02:43<00:10,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 926/986 [02:44<00:10,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 927/986 [02:44<00:10,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 928/986 [02:44<00:10,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 929/986 [02:44<00:10,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 930/986 [02:44<00:09,  5.65it/s]0
#
# Testing DataLoader 0:  94%|█████████▍| 931/986 [02:44<00:09,  5.65it/s]0
#
# Testing DataLoader 0:  95%|█████████▍| 932/986 [02:44<00:09,  5.66it/s]0
#
# Testing DataLoader 0:  95%|█████████▍| 933/986 [02:45<00:09,  5.65it/s]0
#
# Testing DataLoader 0:  95%|█████████▍| 934/986 [02:45<00:09,  5.65it/s]0
#
# Testing DataLoader 0:  95%|█████████▍| 935/986 [02:45<00:09,  5.65it/s]0
#
# Testing DataLoader 0:  95%|█████████▍| 936/986 [02:45<00:08,  5.65it/s]0
#
# Testing DataLoader 0:  95%|█████████▌| 937/986 [02:45<00:08,  5.66it/s]0
#
# Testing DataLoader 0:  95%|█████████▌| 938/986 [02:45<00:08,  5.66it/s]0
#
# Testing DataLoader 0:  95%|█████████▌| 939/986 [02:45<00:08,  5.66it/s]0
#
# Testing DataLoader 0:  95%|█████████▌| 940/986 [02:45<00:08,  5.66it/s]0
#
# Testing DataLoader 0:  95%|█████████▌| 941/986 [02:46<00:07,  5.66it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 942/986 [02:46<00:07,  5.66it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 943/986 [02:46<00:07,  5.66it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 944/986 [02:46<00:07,  5.66it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 945/986 [02:46<00:07,  5.66it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 946/986 [02:46<00:07,  5.67it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 947/986 [02:47<00:06,  5.67it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 948/986 [02:47<00:06,  5.67it/s]0
#
# Testing DataLoader 0:  96%|█████████▌| 949/986 [02:47<00:06,  5.66it/s]0
#
# Testing DataLoader 0:  96%|█████████▋| 950/986 [02:47<00:06,  5.67it/s]0
#
# Testing DataLoader 0:  96%|█████████▋| 951/986 [02:47<00:06,  5.66it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 952/986 [02:47<00:05,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 953/986 [02:48<00:05,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 954/986 [02:48<00:05,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 955/986 [02:48<00:05,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 956/986 [02:48<00:05,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 957/986 [02:48<00:05,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 958/986 [02:48<00:04,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 959/986 [02:49<00:04,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 960/986 [02:49<00:04,  5.67it/s]0
#
# Testing DataLoader 0:  97%|█████████▋| 961/986 [02:49<00:04,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 962/986 [02:49<00:04,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 963/986 [02:50<00:04,  5.66it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 964/986 [02:50<00:03,  5.66it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 965/986 [02:50<00:03,  5.66it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 966/986 [02:50<00:03,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 967/986 [02:50<00:03,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 968/986 [02:50<00:03,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 969/986 [02:50<00:02,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 970/986 [02:51<00:02,  5.67it/s]0
#
# Testing DataLoader 0:  98%|█████████▊| 971/986 [02:51<00:02,  5.67it/s]0
#
# Testing DataLoader 0:  99%|█████████▊| 972/986 [02:51<00:02,  5.67it/s]0
#
# Testing DataLoader 0:  99%|█████████▊| 973/986 [02:51<00:02,  5.67it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 974/986 [02:51<00:02,  5.67it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 975/986 [02:52<00:01,  5.67it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 976/986 [02:52<00:01,  5.67it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 977/986 [02:52<00:01,  5.65it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 978/986 [02:52<00:01,  5.66it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 979/986 [02:53<00:01,  5.66it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 980/986 [02:53<00:01,  5.66it/s]0
#
# Testing DataLoader 0:  99%|█████████▉| 981/986 [02:53<00:00,  5.65it/s]0
#
# Testing DataLoader 0: 100%|█████████▉| 982/986 [02:53<00:00,  5.66it/s]0
#
# Testing DataLoader 0: 100%|█████████▉| 983/986 [02:53<00:00,  5.65it/s]0
#
# Testing DataLoader 0: 100%|█████████▉| 984/986 [02:54<00:00,  5.65it/s]0
#
# Testing DataLoader 0: 100%|█████████▉| 985/986 [02:54<00:00,  5.65it/s]0
#
# Testing DataLoader 0: 100%|██████████| 986/986 [02:54<00:00,  5.65it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.5300620198249817
#         test_wer            0.1442912071943283
#     test_wer_relation       0.12183445692062378
#      test_wer_symbol        0.15579722821712494
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.5300620198249817,
#   'test_wer': 0.1442912071943283,
#   'test_wer_relation': 0.12183445692062378,
#   'test_wer_symbol': 0.15579722821712494}]

# %% [markdown]
# # Bonus 2 (+1 pts for final exam)
#
# Modify loss function to constrain the output of relations at the timestep of pen-up.
#
# The idea: Provide a masked sequence such that the position of pen-up is masked, the additional loss would penaltize all the relations output to the timestep that has been masked.

# %%
#'Above': 101, 'Below': 102, 'Inside': 103, 'NoRel': 104, 'Right': 105, 'Sub': 106, 'Sup': 107
vocab_dict = vocab.word2index
relation = ['Above', 'Below', 'Inside', 'NoRel', 'Right', 'Sub', 'Sup']
relation_idx = [vocab_dict[rel] for rel in relation]

# %%
class RelationLoss(nn.Module):
    def __init__(self, reduction='mean'):
        super(RelationLoss, self).__init__()
        self.reduction = reduction
    def forward(self, y_hat, pen_up):
        _, _, z = y_hat.shape
        
        rel_mask = torch.zeros(z, device=y_hat.device)
        rel_mask[relation_idx] = 1
        
        probs_rel = y_hat * rel_mask
        pen_up = pen_up.unsqueeze(-1)
        pen_down = 1 - pen_up
        
        probs_rel_pen_down = probs_rel * pen_down
        sum_probs_rel_pen_down = probs_rel_pen_down.sum(dim=-1)
        
        loss = -torch.log(1 - sum_probs_rel_pen_down + 1e-8)
        
        if self.reduction == "mean":
            return loss.mean()
        elif self.reduction == "sum":
            return loss.sum()
        
        return loss

# %%
import pytorch_lightning as pl
import torch
from torchmetrics.functional.text.helper import _LevenshteinEditDistance as _LE_distance

class MathOnlineModel2(pl.LightningModule):
    def __init__(self, lr=0.001, input_size=4, output_size=109, hidden_size=128, num_layers = 3, decoder=greedy_decoder, alpha=0.1):
        super().__init__()
        self.model = LSTM_TemporalClassification(input_size, hidden_size, num_layers, output_size)
        self.criterion = nn.CTCLoss(blank=output_size - 1)
        self.lr = lr
        self.decoder = decoder
        self.relationCriterion = RelationLoss()
        self.alpha = alpha

    def forward(self, x):
        return self.model(x)
    
    def training_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)
        relation_loss = self.relationCriterion(y_hat, x[:, :, 3])
        total_loss = loss + self.alpha * relation_loss
        
        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)

        self.log('train_loss', total_loss, prog_bar=True, on_step=True, on_epoch=True)
        self.log('train_wer', total_edits / total_lens, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            print()
            # print("Pred seq:", pred_seq)
            # print("Label seq:", label_seq)
            
            relation_pred = [rel for rel in pred_seq if rel in relation]
            symbol_pred = [rel for rel in pred_seq if rel not in relation]
            # print("Relation pred:", relation_pred)
            # print("Symbol pred:", symbol_pred)
            
            relation_label = [rel for rel in label_seq if rel in relation]
            symbol_label = [rel for rel in label_seq if rel not in relation]
            # print("Relation label:", relation_label)
            # print("Symbol label:", symbol_label)
            
            relation_edit = edit_distance(relation_pred, relation_label)
            relation_lens = len(relation_label)
            
            symbol_edit = edit_distance(symbol_pred, symbol_label)
            symbol_lens = len(symbol_label)        
            
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)

        self.log('val_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('val_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
        
        if relation_lens > 0:
            self.log('val_wer_relation', relation_edit / relation_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('val_wer_relation', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        if symbol_lens > 0:
            self.log('val_wer_symbol', symbol_edit / symbol_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('val_wer_symbol', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        return loss

    def test_step(self, batch, batch_idx):
        x, y, x_lens, y_lens = batch

        # your code to calculate loss
        y_hat = self.model(x)
        y_hat = y_hat.permute(1, 0, 2)
        y_hat = y_hat.log_softmax(2)
        loss = self.criterion(y_hat, y, x_lens, y_lens)

        # your code to calculate total edit distance
        total_edits = 0
        total_lens = 0
        y_hat = y_hat.permute(1, 0, 2)

        # loop: calculate edit distance
        for i in range(x.shape[0]):
            pred_seq = self.decoder(y_hat[i])
            label_seq = [vocab.index2word[index.item()] for index in y[i]]
            print()
            # print("Pred seq:", pred_seq)
            # print("Label seq:", label_seq)
            
            relation_pred = [rel for rel in pred_seq if rel in relation]
            symbol_pred = [rel for rel in pred_seq if rel not in relation]
            # print("Relation pred:", relation_pred)
            # print("Symbol pred:", symbol_pred)
            
            relation_label = [rel for rel in label_seq if rel in relation]
            symbol_label = [rel for rel in label_seq if rel not in relation]
            # print("Relation label:", relation_label)
            # print("Symbol label:", symbol_label)
            
            relation_edit = edit_distance(relation_pred, relation_label)
            relation_lens = len(relation_label)
            
            symbol_edit = edit_distance(symbol_pred, symbol_label)
            symbol_lens = len(symbol_label)        
            
            total_edits += edit_distance(pred_seq, label_seq)
            total_lens += len(label_seq)
            
        
        self.log('test_loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('test_wer', total_edits / total_lens, prog_bar=True, on_step=False, on_epoch=True)
        
        if relation_lens > 0:
            self.log('test_wer_relation', relation_edit / relation_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('test_wer_relation', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        if symbol_lens > 0:
            self.log('test_wer_symbol', symbol_edit / symbol_lens, prog_bar=True, on_step=False, on_epoch=True)
        else:
            self.log('test_wer_symbol', 0, prog_bar=True, on_step=False, on_epoch=True)
        
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=self.lr)
